# %% [markdown]
# # XLS and XLSX files. . Exercise 4
#
# Pandas documentation: https://pandas.pydata.org/docs/index.html
#
# Pandas API reference: https://pandas.pydata.org/docs/reference/index.html#api

# %%
#import pandas library
#importar libraría pandas
import pandas as pd

# %% [markdown]
# ### Sales Dataset
#
# **Source**: Tableau Community
#
# https://community.tableau.com/s/question/0D54T00000CWeX8SAL/sample-superstore-sales-excelxls

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /home/xuwira30/miniconda3
# sistemas              *  /home/xuwira30/miniconda3/envs/sistemas

# %%
# Load XLS file (from local filesystem)

#df = pd.read_excel('../datasets/sample_superstore.xls')
ficheiro = '../datasets/sample_superstore.xls'
#df = pd.read_excel(ficheiro,sheet_name=1)
df = pd.read_excel(ficheiro,sheet_name='Orders')

# %%
# Load XLS file (from local filesystem)
df = pd.read_excel('../datasets/sample_superstore.xls')

# %%
# Load XLS file (from GitHub repo)
url = 'https://github.com/bigdatawirtz/sistemas-bigdata-2023/raw/main/datasets/sample_superstore.xls'
df = pd.read_excel(url,sheet_name='Orders')

# %%
# Cargar ficheiro XLS (dispoñible en repositorio GitHub)
df = pd.read_excel('https://github.com/bigdatawirtz/sistemas-bigdata-2023/raw/main/datasets/sample_superstore.xls', 'Orders')

# %%
# show DataFrame
# mostrar o dataframe
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# Show the 3 first rows filas
# Mostra as 3 primeiras fils
df.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
df.iloc[0:3]
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales  Quantity  \
# ...

# %%
# Show 5 random rows
# Mostra 5 filas aletaorias
df.sample(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 404      405  CA-2017-117933 2017-12-24 2017-12-29  Standard Class
# 6584    6585  CA-2017-104731 2017-07-21 2017-07-27  Standard Class
# 9348    9349  CA-2016-114860 2016-12-22 2016-12-28  Standard Class
# 6579    6580  CA-2016-169887 2016-10-22 2016-10-22        Same Day
# 643      644  CA-2017-106103 2017-06-10 2017-06-15  Standard Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# 404     RF-19840   Roy Französisch  Consumer  United States    New York City
# 6584    AM-10705    Anne McFarland  Consumer  United States            Salem
# 9348    DN-13690      Duane Noonan  Consumer  United States    Moreno Valley
# 6579    MS-17530    MaryBeth Skach  Consumer  United States          Seattle
# 643     SC-20305  Sean Christensen  Consumer  United States  Rochester Hills
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
df.sample(n = 5) # sample() Devuelve registro seleccionado de forma aleatoria
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2152    2153  CA-2015-123505 2015-11-22 2015-11-26  Standard Class
# 9511    9512  CA-2014-130575 2014-12-14 2014-12-16     First Class
# 881      882  CA-2015-129098 2015-10-09 2015-10-13  Standard Class
# 9819    9820  CA-2015-162201 2015-06-08 2015-06-12  Standard Class
# 3940    3941  CA-2017-117863 2017-05-18 2017-05-23  Standard Class
#
#      Customer ID    Customer Name    Segment        Country              City  \
# 2152    AR-10540      Andy Reiter   Consumer  United States            Quincy
# 9511    CS-11845       Cari Sayre  Corporate  United States           Chicago
# 881     DK-13090        Dave Kipp   Consumer  United States       Springfield
# 9819    AG-10495  Andrew Gjertsen  Corporate  United States  Saint Petersburg
# 3940    TS-21340    Toby Swindell   Consumer  United States     New York City
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
# From the last 10 rows, show the 5 first ones
# Das dez últimas filas mostra as 5 primeiras
df.tail(10).head(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9985    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9986    ML-17410      Maris LaWare   Consumer  United States  Los Angeles
# 9987    RA-19885      Ruben Ausman  Corporate  United States       Athens
# 9988    RA-19885      Ruben Ausman  Corporate  United States       Athens
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.iloc[-10:-5]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9985    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# 9986    ML-17410      Maris LaWare   Consumer  United States  Los Angeles
# 9987    RA-19885      Ruben Ausman  Corporate  United States       Athens
# 9988    RA-19885      Ruben Ausman  Corporate  United States       Athens
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Show 3 random rows from the first 50 ones
# Mostra 3 das 50 primeiras filas
df.head(50).sample(3)
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 44      45  CA-2016-118255 2016-03-11 2016-03-13     First Class    ON-18715
# 38      39  CA-2015-117415 2015-12-27 2015-12-31  Standard Class    SN-20710
# 34      35  CA-2017-107727 2017-10-19 2017-10-23    Second Class    MA-17560
#
#     Customer Name      Segment        Country     City  ... Postal Code  \
# 44  Odella Nelson    Corporate  United States    Eagan  ...       55122
# 38   Steve Nguyen  Home Office  United States  Houston  ...       77041
# 34   Matt Abelman  Home Office  United States  Houston  ...       77095
#
#      Region       Product ID         Category Sub-Category  \
# 44  Central  TEC-AC-10000171       Technology  Accessories
# 38  Central  FUR-BO-10002545        Furniture    Bookcases
# 34  Central  OFF-PA-10000249  Office Supplies        Paper
#
#                                          Product Name     Sales  Quantity  \
# ...

# %%
# Show info about column data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# Show the next info
# 
# zip code type: 
# int
# Discount type: 
# float
# Country data type: 
# object -> string

# %%
# zip code type: 
type(df['Postal Code'][0])
# Out:
# numpy.int64

# %%
# Discount type: 
type(df['Discount'][0])
# Out:
# numpy.float64

# %%
# Country data type: 
type(df['Country'][0])
# Out:
# str

# %%
# Show column names
# Mostra os nomes das columnas
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'], dtype=object)

# %%
# Select and show 5 different random cities
# Selección de 5 cidades aleatorias
df.City.sample(5)
# Out:
# 2707         Carlsbad
# 718              Orem
# 6681          Meriden
# 5356    San Francisco
# 8229             Troy
# Name: City, dtype: object

# %%
df['City'].sample(5)
# Out:
# 1109     Houston
# 6769    Columbus
# 3818      Mobile
# 887     Columbia
# 8228        Troy
# Name: City, dtype: object

# %%
# Show the different countries that appear in the data
# Mostra os diferentes países que aparecen nos datos
df.Country.unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
# Show the different categories
# Mostra as diferentes categorías
df.Category.unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# Show the different categories
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# Select client id, name and city
# Selección de id de cliente, nome e cidade
df[['Customer ID', 'Customer Name', 'City']]
# Out:
#      Customer ID     Customer Name             City
# 0       CG-12520       Claire Gute        Henderson
# 1       CG-12520       Claire Gute        Henderson
# 2       DV-13045   Darrin Van Huff      Los Angeles
# 3       SO-20335    Sean O'Donnell  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell  Fort Lauderdale
# ...          ...               ...              ...
# 9989    TB-21400  Tom Boeckenhauer            Miami
# 9990    DB-13060       Dave Brooks       Costa Mesa
# 9991    DB-13060       Dave Brooks       Costa Mesa
# 9992    DB-13060       Dave Brooks       Costa Mesa
# 9993    CC-12220      Chris Cortes      Westminster
#
# [9994 rows x 3 columns]

# %%
# Select Order ID (as Dataframe)
# Selección de IDs de pedido (como Dataframe)
df[['Order ID']]
# Out:
#             Order ID
# 0     CA-2016-152156
# 1     CA-2016-152156
# 2     CA-2016-138688
# 3     US-2015-108966
# 4     US-2015-108966
# ...              ...
# 9989  CA-2014-110422
# 9990  CA-2017-121258
# 9991  CA-2017-121258
# 9992  CA-2017-121258
# 9993  CA-2017-119914
#
# [9994 rows x 1 columns]

# %%
# Count elements in Series "Region"
# Contar elementos totais da serie "Region"
df.Region.count()
# Out:
# 9994

# %%
df['Region'].count()
# Out:
# 9994

# %%
# Show elementes from "Region" Series
# Mostrar elementos da serie "Region"
df.Region.unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
# Count different elements in Series "Region"
# Contar elementos diferentes da serie "Region"
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
len(df.Region.unique())
# Out:
# 4

# %%
# Create a Series with quantities in each order line and show the result
# Crea unha serie cas cantidades de cada liña de pedido e mostra o resultado
cantidades = df.Quantity
cantidades
# Out:
# 0       2
# 1       3
# 2       2
# 3       5
# 4       2
#        ..
# 9989    3
# 9990    2
# 9991    2
# 9992    4
# 9993    2
# Name: Quantity, Length: 9994, dtype: int64

# %%
# Show the lines with quantities greater than 2
# Mostra só as liñas do dataframe que conteñan liñas de pedido con cantidades maiores que 2
df[df['Quantity'] > 2]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985    9986  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# Show only the DataFrame lines with subcategory  "Tables"
# Mostra só as liñas do dataframe que conteñan liñas de pedido da subcategoría de mesas "Tables"
df[df['Sub-Category'] == 'Tables']
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 24        25  CA-2015-106320 2015-09-25 2015-09-30  Standard Class
# 117      118  CA-2015-110457 2015-03-02 2015-03-06  Standard Class
# 125      126  US-2014-134614 2014-09-20 2014-09-25  Standard Class
# ...      ...             ...        ...        ...             ...
# 9857    9858  CA-2015-164301 2015-03-26 2015-03-30  Standard Class
# 9899    9900  US-2014-117380 2014-03-28 2014-04-03  Standard Class
# 9937    9938  CA-2016-164889 2016-06-03 2016-06-06    Second Class
# 9955    9956  CA-2015-141593 2015-12-14 2015-12-16    Second Class
# 9980    9981  US-2015-151435 2015-09-06 2015-09-09    Second Class
#
#      Customer ID    Customer Name      Segment        Country  \
# 3       SO-20335   Sean O'Donnell     Consumer  United States
# ...

# %%
# Show the cities with orders including "Tables"
# Mostra as cidades con pedidos que inclúen mesas
df[df['Sub-Category'] == 'Tables'].City.unique()
# Out:
# array(['Fort Lauderdale', 'Los Angeles', 'Orem', 'Seattle', 'Bloomington',
#        'Denver', 'Detroit', 'Tampa', 'Chicago', 'San Francisco',
#        'Franklin', 'Pembroke Pines', 'Akron', 'Phoenix', 'Memphis',
#        'Arlington', 'Long Beach', 'Oceanside', 'San Diego',
#        'Jacksonville', 'Edmonds', 'San Antonio', 'Torrance', 'Mesa',
#        'Philadelphia', 'New York City', 'Saint Peters', 'Yonkers',
#        'Springfield', 'Harrisonburg', 'Fresno', 'Provo', 'Aurora',
#        'Columbus', 'Vineland', 'North Las Vegas', 'Dublin', 'Muskogee',
#        'Spokane', 'Fairfield', 'Miami', 'Pomona', 'Wilmington',
#        'Rochester', 'Southaven', 'Louisville', 'Passaic', 'Houston',
#        'Bellingham', 'Wheeling', 'Milwaukee', 'Encinitas', 'Allen',
#        'Pasadena', 'Oakland', 'Quincy', 'Bristol', 'Charlotte',
#        'Lancaster', 'Dallas', 'Jackson', 'Greensboro', 'Mobile', 'Boise',
#        'Cranston', 'Redmond', 'Henderson', 'Mentor', 'Lawton',
# ...

# %%
# Create a variable (type Series) of cities with orders including Tables. Show 5 random elements.
# Crea unha variable de tipo Series coas cidades con pedidos que inclúen mesas e mostra 5 filas aleatorias
cidades_que_piden_mesas = pd.Series(df[df['Sub-Category'] == 'Tables'].City.unique())
cidades_que_piden_mesas.sample(5)
# Out:
# 92     Montgomery
# 3         Seattle
# 34       Vineland
# 32         Aurora
# 103         Pharr
# dtype: object

# %%
# Create a variable (type DataFrame) of cities with orders including Chairs. Show the 3 last elements.
# Crea unha variable de tipo Dataframe coas cidades con pedidos que inclúen sillas e mostra as 3 últimas
cidades_que_piden_mesas = pd.DataFrame(df[df['Sub-Category'] == 'Chairs'].City.unique(),columns=['cidade'])
cidades_que_piden_mesas.tail(3)
# Out:
#             cidade
# 192  Santa Barbara
# 193          Bryan
# 194   Indianapolis

# %%
# Show all the order lines including Phones to 'Los Angeles'
# Mostra todas as liñas de pedido de teléfonos (Phones) para 'Los Angeles'
df[(df['Sub-Category'] == 'Phones') & (df['City'] == 'Los Angeles')]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 11        12  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 90        91  CA-2016-109806 2016-09-17 2016-09-22  Standard Class
# 218      219  CA-2016-130162 2016-10-28 2016-11-01  Standard Class
# 477      478  CA-2016-103891 2016-07-12 2016-07-19  Standard Class
# ...      ...             ...        ...        ...             ...
# 9234    9235  CA-2016-126732 2016-09-02 2016-09-06  Standard Class
# 9454    9455  CA-2015-129546 2015-09-28 2015-10-05  Standard Class
# 9764    9765  CA-2014-123855 2014-06-18 2014-06-23  Standard Class
# 9973    9974  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9976    9977  US-2016-103674 2016-12-06 2016-12-10  Standard Class
#
#      Customer ID     Customer Name      Segment        Country         City  \
# 7       BH-11710   Brosina Hoffman     Consumer  United States  Los Angeles
# ...

# %%
# Show 10 random order lines with Phones or Tables
# Mostra 10 liñas exemplo de pedido de teléfonos (Phones) ou mesas (Tables)
df[(df['Sub-Category'] == 'Phones') | (df['Sub-Category'] == 'Tables')].sample(10)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 8958    8959  CA-2017-150266 2017-11-25 2017-11-30  Standard Class
# 5487    5488  CA-2017-134495 2017-04-01 2017-04-04    Second Class
# 486      487  CA-2017-140963 2017-06-10 2017-06-13     First Class
# 6578    6579  CA-2014-103660 2014-08-25 2014-08-30  Standard Class
# 1750    1751  CA-2015-139094 2015-11-22 2015-11-27  Standard Class
# 7409    7410  CA-2014-121769 2014-04-08 2014-04-12  Standard Class
# 5062    5063  CA-2015-136798 2015-05-08 2015-05-12  Standard Class
# 5009    5010  CA-2015-102876 2015-09-07 2015-09-14  Standard Class
# 4056    4057  CA-2014-122931 2014-09-29 2014-10-03  Standard Class
# 9391    9392  CA-2017-162474 2017-03-13 2017-03-16     First Class
#
#      Customer ID      Customer Name      Segment        Country          City  \
# 8958    RO-19780       Rose O'Brian     Consumer  United States       Houston
# ...

# %%
# Select the second row of the dataframe
# Selecciona a segunda fila do dataframe
df.iloc[[1]]
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
#
#   Customer Name   Segment        Country       City  ... Postal Code  Region  \
# 1   Claire Gute  Consumer  United States  Henderson  ...       42420   South
#
#         Product ID   Category Sub-Category  \
# 1  FUR-CH-10000454  Furniture       Chairs
#
#                                         Product Name   Sales  Quantity  \
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#    Discount   Profit
# 1       0.0  219.582
#
# [1 rows x 21 columns]

# %%
# Select the third, seventh and 24 row of the dataset
# Selecciona a terceira, séptima e vixésima cuarta fila
df.iloc[[2,6,23]]
# Out:
#     Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2        3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 6        7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 23      24  US-2017-156909 2017-07-16 2017-07-18    Second Class    SF-20065
#
#       Customer Name    Segment        Country          City  ... Postal Code  \
# 2   Darrin Van Huff  Corporate  United States   Los Angeles  ...       90036
# 6   Brosina Hoffman   Consumer  United States   Los Angeles  ...       90032
# 23  Sandra Flanagan   Consumer  United States  Philadelphia  ...       19140
#
#     Region       Product ID         Category Sub-Category  \
# 2     West  OFF-LA-10000240  Office Supplies       Labels
# 6     West  OFF-AR-10002833  Office Supplies          Art
# 23    East  FUR-CH-10002774        Furniture       Chairs
#
#                                          Product Name   Sales  Quantity  \
# ...

# %%
# create a dataframe (sales) with the client name, city, product name and quantity from West region
# crea un dataframe (vendas) co nome de cliente, cidade, nome do produto e cantidade comprada da rexión oeste
sales = df[df.Region == 'West'][['Customer Name','City','Product Name']]
sales
# Out:
#         Customer Name         City  \
# 2     Darrin Van Huff  Los Angeles
# 5     Brosina Hoffman  Los Angeles
# 6     Brosina Hoffman  Los Angeles
# 7     Brosina Hoffman  Los Angeles
# 8     Brosina Hoffman  Los Angeles
# ...               ...          ...
# 9986     Maris LaWare  Los Angeles
# 9990      Dave Brooks   Costa Mesa
# 9991      Dave Brooks   Costa Mesa
# 9992      Dave Brooks   Costa Mesa
# 9993     Chris Cortes  Westminster
#
#                                            Product Name
# 2     Self-Adhesive Address Labels for Typewriters b...
# 5     Eldon Expressions Wood and Plastic Desk Access...
# 6                                            Newell 322
# 7                        Mitel 5320 IP Phone VoIP phone
# 8     DXL Angle-View Binders with Locking Rings by S...
# ...                                                 ...
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...
# ...

# %%
# Select the second row from the previous DataFrame (sales) using position
# Seleccionar a segunda fila do dataframe anterior (vendas) atendendendo á posición
sales.iloc[[1]]
# Out:
#      Customer Name         City  \
# 5  Brosina Hoffman  Los Angeles
#
#                                         Product Name
# 5  Eldon Expressions Wood and Plastic Desk Access...

# %%
# Select the second row from the previous DataFrame (sales) using index
# Seleccionar a segunda fila de vendas atendendo ao index (mira o dataframe)
sales.loc[[5]]
# Out:
#      Customer Name         City  \
# 5  Brosina Hoffman  Los Angeles
#
#                                         Product Name
# 5  Eldon Expressions Wood and Plastic Desk Access...

# %%
# Think about what's the best column in the spreadsheet to use it as an index and load the file again in a new DataFrame
# Pensa se hai algunha columna no ficheiro excel que puidese funcionar como index e volve cargar o dataframe 
df = pd.read_excel(ficheiro,index_col='Row ID',sheet_name='Orders')
df.head()
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 3       CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4       US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#           Customer Name    Segment        Country             City  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              State  Postal Code Region       Product ID         Category  \
# Row ID
# ...

# %%
# Select the fifth row
# Seleccionar a quinta fila
df.iloc[[4]]
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 5       US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#          Customer Name   Segment        Country             City    State  \
# Row ID
# 5       Sean O'Donnell  Consumer  United States  Fort Lauderdale  Florida
#
#         Postal Code Region       Product ID         Category Sub-Category  \
# Row ID
# 5             33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                           Product Name   Sales  Quantity  Discount  Profit
# Row ID
# 5       Eldon Fold 'N Roll Cart System  22.368         2       0.2  2.5164

# %%
# Select rows from the third to the seventh one
# Seleccionar as filas desde a terceira á séptima
df.iloc[2:7]
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 3       CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4       US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 6       CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#           Customer Name    Segment        Country             City  \
# Row ID
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 6       Brosina Hoffman   Consumer  United States      Los Angeles
# 7       Brosina Hoffman   Consumer  United States      Los Angeles
#
#              State  Postal Code Region       Product ID         Category  \
# Row ID
# ...

# %%
# Selecdt penultimate row
# Seleccionar a penúltima fila
df.iloc[[-2]]
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 9993    CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
#
#        Customer Name   Segment        Country        City       State  \
# Row ID
# 9993     Dave Brooks  Consumer  United States  Costa Mesa  California
#
#         Postal Code Region       Product ID         Category Sub-Category  \
# Row ID
# 9993          92627   West  OFF-PA-10004041  Office Supplies        Paper
#
#                                              Product Name  Sales  Quantity  \
# Row ID
# 9993    It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6         4
#
#         Discount  Profit
# Row ID
# 9993         0.0   13.32

# %%
# Select, given the last 5 rows, all but the last one.
# Seleccionar, das 5 últimas filas, todas menos a última
df.iloc[-5:-1]
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 9990    CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9991    CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992    CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993    CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
#
#            Customer Name   Segment        Country        City       State  \
# Row ID
# 9990    Tom Boeckenhauer  Consumer  United States       Miami     Florida
# 9991         Dave Brooks  Consumer  United States  Costa Mesa  California
# 9992         Dave Brooks  Consumer  United States  Costa Mesa  California
# 9993         Dave Brooks  Consumer  United States  Costa Mesa  California
#
#         Postal Code Region       Product ID         Category Sub-Category  \
# Row ID
# 9990          33180  South  FUR-FU-10001889        Furniture  Furnishings
# ...

# %%
# Depending on what we need, we can use loc or iloc
# loc <- work with index/labels
# iloc <- work with positions

# %%
# conda install openpyxl
# Write to XLS all the sales in the State of California
# Escritura dun ficheiro XLS coas vendas no estado de California
vendas_california = df[df['State'] == 'California']
vendas_california.to_excel('output/vendas_california.xlsx')

# %%
# Give a name to the sheet ('California')
# Darlle un nome á folla ('California')
vendas_california.to_excel('output/vendas_california.xlsx',sheet_name='California')

# %%
# Save the sales rows in the west or south. 
# Save the product name, identifier, quantity and discount. 
# Save the result in a file sales_WS.xlsx
# Try to do it all in a single row

# Garda as filas de vendas da zona oeste ou sur. Desas filas garda unicamente nome do produto, identificador, cantidade e desconto. Garda o resultado nun ficheiro vendas_WS.xlsx
# Intenta facelo todo nunha única liña
df[(df.Region == 'West') | (df.Region == 'South')][['Product Name','Product ID','Quantity','Discount']].to_excel('output/vendas_WS.xlsx')
