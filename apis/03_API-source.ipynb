# %% [markdown]
# ### API's. 3

# %%
import requests

# %% [markdown]
# #### AUTHENTICATION
# Some APIs require authentication
# - Some of the reasons may be:
# - they are a paid service offered by a company
# - They are very demanding at the processing level and impose limitations
# - ...

# %% [markdown]
# ### currencyconvertapi.com
# Currency conversion api
#
# https://www.currencyconverterapi.com/
#
# **SERVICE CURRENTLY VERY LIMITED (2023)**
#
# Please take into account the documentation
#
# https://www.currencyconverterapi.com/docs

# %%
# List conversions
url = 'https://free.currconv.com/api/v7/currencies'
response = requests.get(url)
response.json()
#response.url

# service requires authentication
# Out:
# {'status': 400, 'error': 'API Key is required.'}

# %% [markdown]
# Request a new API KEY (valid for a month)
#
# Check if the server is up or down
#
# https://free.currencyconverterapi.com/
#
# May take days to create the API-KEY!!!

# %%
# Listar cambios: con API KEY

url  = 'https://free.currconv.com/api/v7/currencies'
#API_KEY = 'a_minha_api_key'
API_KEY = 'a_minha_api_key'

response = requests.get(url, params = {'apiKey':API_KEY})
response.json()
#response.url
# Out:
# {'status': 400,
#  'error': "Invalid Free API Key. If you're a premium user, use the api key on https://api. instead of https://free."}

# %% [markdown]
# ### exchangeratesapi.io
# Alternative for currency exchange
#
# Exchangerates offers information services on currency exchange
#
# Register to get an API-KEY
#
# https://exchangeratesapi.io/
#
# Read the documentation
#
# https://exchangeratesapi.io/documentation/

# %%
# Listar cambios
url  = 'https://api.exchangeratesapi.io/v1/'
response = requests.get(url)
response.json()
#response.url
# Out:
# {'error': {'code': 'missing_access_key',
#   'message': 'You have not supplied an API Access Key. [Required format: access_key=YOUR_ACCESS_KEY]'}}

# %%
# http://api.exchangeratesapi.io/v1/
# http://api.exchangeratesapi.io/v1/latest?access_key=08e6e099041473b9af52120ae48619a7

url  = 'http://api.exchangeratesapi.io/v1/latest'
API_KEY = '08e6e099041473b9af52120ae48619a7'
response = requests.get(url, params = {'access_key':API_KEY})
response.json()
#response.url
# Out:
# {'success': True,
#  'timestamp': 1705336563,
#  'base': 'EUR',
#  'date': '2024-01-15',
#  'rates': {'AED': 4.021442,
#   'AFN': 77.738489,
#   'ALL': 103.681298,
#   'AMD': 442.406851,
#   'ANG': 1.971376,
#   'AOA': 907.390161,
#   'ARS': 895.323838,
#   'AUD': 1.644303,
#   'AWG': 1.973601,
#   'AZN': 1.86415,
#   'BAM': 1.954487,
#   'BBD': 2.208738,
#   'BDT': 120.049356,
#   'BGN': 1.957463,
#   'BHD': 0.412732,
#   'BIF': 3116.834713,
#   'BMD': 1.094924,
#   'BND': 1.458534,
#   'BOB': 7.557992,
#   'BRL': 5.337814,
#   'BSD': 1.093875,
#   'BTC': 2.581796e-05,
#   'BTN': 90.645808,
#   'BWP': 14.801057,
#   'BYN': 3.579628,
#   'BYR': 21460.519761,
#   'BZD': 2.204839,
#   'CAD': 1.472175,
#   'CDF': 2956.295921,
#   'CHF': 0.935985,
#   'CLF': 0.036154,
#   'CLP': 997.859171,
#   'CNY': 7.780097,
#   'COP': 4279.216691,
#   'CRC': 568.518094,
#   'CUC': 1.094924,
#   'CUP': 29.015499,
#   'CVE': 110.191984,
#   'CZK': 24.694267,
#   'DJF': 194.750953,
#   'DKK': 7.458075,
#   'DOP': 64.106936,
#   'DZD': 147.4755,
#   'EGP': 33.884081,
#   'ERN': 16.423867,
#   'ETB': 61.863708,
#   'EUR': 1,
#   'FJD': 2.433196,
#   'FKP': 0.858698,
#   'GBP': 0.859888,
#   'GEL': 2.931654,
#   'GGP': 0.858698,
#   'GHS': 13.126302,
#   'GIP': 0.858698,
#   'GMD': 73.661033,
#   'GNF': 9400.685031,
#   'GTQ': 8.553254,
#   'GYD': 229.028241,
#   'HKD': 8.564664,
#   'HNL': 26.972881,
#   'HRK': 7.533431,
#   'HTG': 143.994586,
#   'HUF': 379.01926,
#   'IDR': 17021.312705,
#   'ILS': 4.108759,
#   'IMP': 0.858698,
#   'INR': 90.679675,
#   'IQD': 1433.081291,
#   'IRR': 46101.79479,
#   'ISK': 149.303675,
#   'JEP': 0.858698,
#   'JMD': 170.075751,
#   'JOD': 0.776851,
#   'JPY': 159.609295,
#   'KES': 175.187656,
#   'KGS': 97.798717,
#   'KHR': 4464.001279,
#   'KMF': 492.258043,
#   'KPW': 985.432024,
#   'KRW': 1448.09266,
#   'KWD': 0.336514,
#   'KYD': 0.911488,
#   'KZT': 494.182543,
#   'LAK': 22573.042577,
#   'LBP': 16440.206337,
#   'LKR': 352.556388,
#   'LRD': 206.99565,
#   'LSL': 20.442524,
#   'LTL': 3.233027,
#   'LVL': 0.662309,
#   'LYD': 5.249474,
#   'MAD': 10.889185,
#   'MDL': 19.333189,
#   'MGA': 4987.649515,
#   'MKD': 61.545043,
#   'MMK': 2297.056938,
#   'MNT': 3735.895534,
#   'MOP': 8.811761,
#   'MRU': 43.362208,
#   'MUR': 49.76447,
#   'MVR': 16.799609,
#   'MWK': 1841.379859,
#   'MXN': 18.503242,
#   'MYR': 5.091739,
#   'MZN': 69.253918,
#   'NAD': 20.441914,
#   'NGN': 1048.992368,
#   'NIO': 40.053094,
#   'NOK': 11.338414,
#   'NPR': 145.033573,
#   'NZD': 1.766995,
#   'OMR': 0.421517,
#   'PAB': 1.093775,
#   'PEN': 4.04838,
#   'PGK': 4.087254,
#   'PHP': 61.030537,
#   'PKR': 306.541679,
#   'PLN': 4.366683,
#   'PYG': 7948.660437,
#   'QAR': 3.986346,
#   'RON': 4.973802,
#   'RSD': 117.240122,
#   'RUB': 96.309671,
#   'RWF': 1394.663126,
#   'SAR': 4.106304,
#   'SBD': 9.225243,
#   'SCR': 15.709964,
#   'SDG': 658.049778,
#   'SEK': 11.292104,
#   'SGD': 1.460208,
#   'SHP': 1.395864,
#   'SLE': 25.084737,
#   'SLL': 21624.758772,
#   'SOS': 625.201919,
#   'SRD': 40.348122,
#   'STD': 22662.726042,
#   'SYP': 14236.027015,
#   'SZL': 20.423467,
#   'THB': 38.322132,
#   'TJS': 11.944476,
#   'TMT': 3.832236,
#   'TND': 3.38715,
#   'TOP': 2.573456,
#   'TRY': 32.955327,
#   'TTD': 7.42801,
#   'TWD': 34.239165,
#   'TZS': 2748.812346,
#   'UAH': 41.503919,
#   'UGX': 4169.199314,
#   'USD': 1.094924,
#   'UYU': 43.10144,
#   'UZS': 13502.929322,
#   'VEF': 3932498.405737,
#   'VES': 39.330792,
#   'VND': 26803.751211,
#   'VUV': 129.071287,
#   'WST': 2.937028,
#   'XAF': 655.516653,
#   'XAG': 0.047172,
#   'XAU': 0.000533,
#   'XCD': 2.959088,
#   'XDR': 0.818658,
#   'XOF': 655.522635,
#   'XPF': 119.331742,
#   'YER': 274.141716,
#   'ZAR': 20.477608,
#   'ZMK': 9855.630257,
#   'ZMW': 28.620036,
#   'ZWL': 352.565235}}

# %%
# If we want to select a specific value, for example: 'GBP'.
response.json()['rates']['GBP']
# Out:
# 0.859888

# %%
# Specify currencies
# The API also allows us to choose the currencies for which we want to consult the exchange rate
# (we always use EURO base)
# The exchange rate (currently) has become a service only accessible in the payment subscription.

url  = 'http://api.exchangeratesapi.io/v1/latest'
API_KEY = '08e6e099041473b9af52120ae48619a7'
payload = {'access_key':API_KEY, 'symbols':'USD,CAD,JPY'}
response = requests.get(url, params = payload )
response.json()
#response.url
# Out:
# {'success': True,
#  'timestamp': 1705336625,
#  'base': 'EUR',
#  'date': '2024-01-15',
#  'rates': {'USD': 1.094972, 'CAD': 1.472185, 'JPY': 159.621246}}

# %%
# CURRENCY CONVERSION

# (this service also became a paid service)
# documentation: https://exchangeratesapi.io/documentation/#latestrates

url  = 'http://api.exchangeratesapi.io/v1/convert'
API_KEY = '08e6e099041473b9af52120ae48619a7'
payload = {'access_key':API_KEY, 'from':'EU','to':'GBP', 'amount':10}
response = requests.get(url, params = payload )
response.json()
#response.url
# Out:
# {'error': {'code': 'function_access_restricted',
#   'message': 'Access Restricted - Your current Subscription Plan does not support this API Function.'}}

# %% [markdown]
# The authentication we pass as parameter is not secure at all.
#
# There are other methods of authentication that are more secure. For example, sending the information of a token in the header

# %%
# Sending a token as a parameter

url = 'http://httpbin.org/get'
payload = { 'token': 'O-MEU-TOKEN-XENIAL'}
response = requests.get(url, params = payload )
response.json()
# Out:
# {'args': {'token': 'O-MEU-TOKEN-XENIAL'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-65a55fff-1b8c0d6d681594e7667f0341'},
#  'origin': '195.57.104.123',
#  'url': 'http://httpbin.org/get?token=O-MEU-TOKEN-XENIAL'}

# %%
# the information goes in the headers, not in the url
response.url
# Out:
# 'http://httpbin.org/get'

# %%
# Sending a token in the headers

url = 'http://httpbin.org/get'
token = { 'token': 'O-MEU-TOKEN-XENIAL'}
response = requests.get(url, headers = token )
response.json()
# Out:
# {'args': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'Token': 'O-MEU-TOKEN-XENIAL',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-65a56039-69932fa3505a0c30345fee40'},
#  'origin': '195.57.104.123',
#  'url': 'http://httpbin.org/get'}

# %%
# the information goes in the headers, not in the url
response.url
# Out:
# 'http://httpbin.org/get'

# %% [markdown]
# ### openweathermap.org
#
# OpenWeatherMap is a page that offers weather information.
#
# Requires registration to access some services but it offers a free layer.
#
# https://openweathermap.org/
#
# Register and get an API-KEY
# - Register -> Create an account
# - View API-KEY

# %%
# Documentacion: How to Start
# https://openweathermap.org/appid
# mi API-KEY 3d7302197b47bf80fe9fd0542b0e51f8
API_KEY='3d7302197b47bf80fe9fd0542b0e51f8'
url ='http://api.openweathermap.org/data/2.5/forecast'
response = requests.get(url, params = {'id':524901, 'appid':API_KEY})
response.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1705341600,
#    'main': {'temp': 270.59,
#     'feels_like': 264.88,
#     'temp_min': 268.92,
#     'temp_max': 270.59,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 976,
#     'humidity': 94,
#     'temp_kf': 1.67},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.25, 'deg': 180, 'gust': 12.61},
#    'visibility': 273,
#    'pop': 0.32,
#    'snow': {'3h': 0.19},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-15 18:00:00'},
#   {'dt': 1705352400,
#    'main': {'temp': 270.15,
#     'feels_like': 263.98,
#     'temp_min': 269.27,
#     'temp_max': 270.15,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 975,
#     'humidity': 93,
#     'temp_kf': 0.88},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.84, 'deg': 187, 'gust': 13.45},
#    'visibility': 579,
#    'pop': 1,
#    'snow': {'3h': 0.38},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-15 21:00:00'},
#   {'dt': 1705363200,
#    'main': {'temp': 269.3,
#     'feels_like': 262.99,
#     'temp_min': 268.66,
#     'temp_max': 269.3,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 975,
#     'humidity': 92,
#     'temp_kf': 0.64},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.7, 'deg': 191, 'gust': 13.05},
#    'visibility': 8629,
#    'pop': 0.76,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 00:00:00'},
#   {'dt': 1705374000,
#    'main': {'temp': 268.47,
#     'feels_like': 262.12,
#     'temp_min': 268.47,
#     'temp_max': 268.47,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 975,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.4, 'deg': 192, 'gust': 13.22},
#    'visibility': 10000,
#    'pop': 0.26,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 03:00:00'},
#   {'dt': 1705384800,
#    'main': {'temp': 267.81,
#     'feels_like': 261.87,
#     'temp_min': 267.81,
#     'temp_max': 267.81,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 976,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.56, 'deg': 192, 'gust': 12.07},
#    'visibility': 10000,
#    'pop': 0.08,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-16 06:00:00'},
#   {'dt': 1705395600,
#    'main': {'temp': 268.4,
#     'feels_like': 263.1,
#     'temp_min': 268.4,
#     'temp_max': 268.4,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 976,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 3.91, 'deg': 180, 'gust': 10.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-16 09:00:00'},
#   {'dt': 1705406400,
#    'main': {'temp': 269.85,
#     'feels_like': 265.09,
#     'temp_min': 269.85,
#     'temp_max': 269.85,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 975,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 3.65, 'deg': 185, 'gust': 7.65},
#    'visibility': 8988,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-16 12:00:00'},
#   {'dt': 1705417200,
#    'main': {'temp': 269.51,
#     'feels_like': 264.74,
#     'temp_min': 269.51,
#     'temp_max': 269.51,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 974,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.58, 'deg': 200, 'gust': 7.55},
#    'visibility': 8168,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 15:00:00'},
#   {'dt': 1705428000,
#    'main': {'temp': 265.14,
#     'feels_like': 261.54,
#     'temp_min': 265.14,
#     'temp_max': 265.14,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 974,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.89, 'deg': 203, 'gust': 3.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 18:00:00'},
#   {'dt': 1705438800,
#    'main': {'temp': 262.14,
#     'feels_like': 257.04,
#     'temp_min': 262.14,
#     'temp_max': 262.14,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 975,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 2.53, 'deg': 219, 'gust': 7.39},
#    'visibility': 6969,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 21:00:00'},
#   {'dt': 1705449600,
#    'main': {'temp': 265.16,
#     'feels_like': 258.72,
#     'temp_min': 265.16,
#     'temp_max': 265.16,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 976,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 4.38, 'deg': 240, 'gust': 10.37},
#    'visibility': 3049,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 00:00:00'},
#   {'dt': 1705460400,
#    'main': {'temp': 264.54,
#     'feels_like': 257.56,
#     'temp_min': 264.54,
#     'temp_max': 264.54,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 978,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.87, 'deg': 256, 'gust': 11.38},
#    'visibility': 771,
#    'pop': 0.26,
#    'snow': {'3h': 0.22},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 03:00:00'},
#   {'dt': 1705471200,
#    'main': {'temp': 262.05,
#     'feels_like': 255.05,
#     'temp_min': 262.05,
#     'temp_max': 262.05,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 981,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.99, 'deg': 273, 'gust': 12.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 06:00:00'},
#   {'dt': 1705482000,
#    'main': {'temp': 261.15,
#     'feels_like': 254.15,
#     'temp_min': 261.15,
#     'temp_max': 261.15,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 985,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.14, 'deg': 265, 'gust': 12.15},
#    'visibility': 6357,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 09:00:00'},
#   {'dt': 1705492800,
#    'main': {'temp': 260.22,
#     'feels_like': 253.22,
#     'temp_min': 260.22,
#     'temp_max': 260.22,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 988,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6, 'deg': 267, 'gust': 12.2},
#    'visibility': 5883,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 12:00:00'},
#   {'dt': 1705503600,
#    'main': {'temp': 259.41,
#     'feels_like': 252.41,
#     'temp_min': 259.41,
#     'temp_max': 259.41,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 991,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.67, 'deg': 268, 'gust': 13.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 15:00:00'},
#   {'dt': 1705514400,
#    'main': {'temp': 259.06,
#     'feels_like': 252.06,
#     'temp_min': 259.06,
#     'temp_max': 259.06,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 994,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 4.65, 'deg': 262, 'gust': 13.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 18:00:00'},
#   {'dt': 1705525200,
#    'main': {'temp': 259.64,
#     'feels_like': 252.64,
#     'temp_min': 259.64,
#     'temp_max': 259.64,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 997,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 4.05, 'deg': 245, 'gust': 11.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 21:00:00'},
#   {'dt': 1705536000,
#    'main': {'temp': 257.31,
#     'feels_like': 250.35,
#     'temp_min': 257.31,
#     'temp_max': 257.31,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 998,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 3.2, 'deg': 225, 'gust': 10.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 00:00:00'},
#   {'dt': 1705546800,
#    'main': {'temp': 256.37,
#     'feels_like': 250.15,
#     'temp_min': 256.37,
#     'temp_max': 256.37,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 997,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 2.56, 'deg': 172, 'gust': 8.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 03:00:00'},
#   {'dt': 1705557600,
#    'main': {'temp': 261.28,
#     'feels_like': 254.28,
#     'temp_min': 261.28,
#     'temp_max': 261.28,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 995,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 4.8, 'deg': 157, 'gust': 16.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 06:00:00'},
#   {'dt': 1705568400,
#    'main': {'temp': 264.41,
#     'feels_like': 257.41,
#     'temp_min': 264.41,
#     'temp_max': 264.41,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 991,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.98, 'deg': 153, 'gust': 20.76},
#    'visibility': 5928,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 09:00:00'},
#   {'dt': 1705579200,
#    'main': {'temp': 265.9,
#     'feels_like': 258.9,
#     'temp_min': 265.9,
#     'temp_max': 265.9,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 985,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.12, 'deg': 157, 'gust': 20.83},
#    'visibility': 137,
#    'pop': 1,
#    'snow': {'3h': 2.95},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 12:00:00'},
#   {'dt': 1705590000,
#    'main': {'temp': 268.35,
#     'feels_like': 261.35,
#     'temp_min': 268.35,
#     'temp_max': 268.35,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 980,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.88, 'deg': 161, 'gust': 18},
#    'visibility': 147,
#    'pop': 1,
#    'snow': {'3h': 2.18},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 15:00:00'},
#   {'dt': 1705600800,
#    'main': {'temp': 272.93,
#     'feels_like': 267.22,
#     'temp_min': 272.93,
#     'temp_max': 272.93,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 976,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.42, 'deg': 173, 'gust': 15.95},
#    'visibility': 118,
#    'pop': 1,
#    'snow': {'3h': 2.44},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 18:00:00'},
#   {'dt': 1705611600,
#    'main': {'temp': 273.93,
#     'feels_like': 268.65,
#     'temp_min': 273.93,
#     'temp_max': 273.93,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 974,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.09, 'deg': 184, 'gust': 16.74},
#    'visibility': 61,
#    'pop': 1,
#    'snow': {'3h': 4.05},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 21:00:00'},
#   {'dt': 1705622400,
#    'main': {'temp': 274.61,
#     'feels_like': 269.62,
#     'temp_min': 274.61,
#     'temp_max': 274.61,
#     'pressure': 991,
#     'sea_level': 991,
#     'grnd_level': 973,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.85, 'deg': 200, 'gust': 15.05},
#    'visibility': 45,
#    'pop': 1,
#    'snow': {'3h': 1.94},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 00:00:00'},
#   {'dt': 1705633200,
#    'main': {'temp': 273.8,
#     'feels_like': 269.52,
#     'temp_min': 273.8,
#     'temp_max': 273.8,
#     'pressure': 991,
#     'sea_level': 991,
#     'grnd_level': 972,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.22, 'deg': 209, 'gust': 12.99},
#    'visibility': 30,
#    'pop': 1,
#    'snow': {'3h': 1.93},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 03:00:00'},
#   {'dt': 1705644000,
#    'main': {'temp': 273.84,
#     'feels_like': 269.75,
#     'temp_min': 273.84,
#     'temp_max': 273.84,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 974,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.95, 'deg': 238, 'gust': 9.55},
#    'visibility': 23,
#    'pop': 1,
#    'snow': {'3h': 1.18},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 06:00:00'},
#   {'dt': 1705654800,
#    'main': {'temp': 272.97,
#     'feels_like': 267.68,
#     'temp_min': 272.97,
#     'temp_max': 272.97,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 979,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.6, 'deg': 281, 'gust': 10.52},
#    'visibility': 10000,
#    'pop': 0.2,
#    'snow': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 09:00:00'},
#   {'dt': 1705665600,
#    'main': {'temp': 269.89,
#     'feels_like': 264.25,
#     'temp_min': 269.89,
#     'temp_max': 269.89,
#     'pressure': 1001,
#     'sea_level': 1001,
#     'grnd_level': 982,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 4.86, 'deg': 261, 'gust': 11.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 12:00:00'},
#   {'dt': 1705676400,
#    'main': {'temp': 267.72,
#     'feels_like': 261.6,
#     'temp_min': 267.72,
#     'temp_max': 267.72,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 987,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.78, 'deg': 260, 'gust': 11.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 15:00:00'},
#   {'dt': 1705687200,
#    'main': {'temp': 265.81,
#     'feels_like': 259.55,
#     'temp_min': 265.81,
#     'temp_max': 265.81,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 990,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.35, 'deg': 270, 'gust': 11.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 18:00:00'},
#   {'dt': 1705698000,
#    'main': {'temp': 264.07,
#     'feels_like': 257.98,
#     'temp_min': 264.07,
#     'temp_max': 264.07,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 993,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.72, 'deg': 269, 'gust': 10.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 21:00:00'},
#   {'dt': 1705708800,
#    'main': {'temp': 261.62,
#     'feels_like': 255.48,
#     'temp_min': 261.62,
#     'temp_max': 261.62,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 996,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 3.27, 'deg': 268, 'gust': 9.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 00:00:00'},
#   {'dt': 1705719600,
#    'main': {'temp': 259.33,
#     'feels_like': 253.67,
#     'temp_min': 259.33,
#     'temp_max': 259.33,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 998,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 2.56, 'deg': 274, 'gust': 7.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 03:00:00'},
#   {'dt': 1705730400,
#    'main': {'temp': 257.2,
#     'feels_like': 252,
#     'temp_min': 257.2,
#     'temp_max': 257.2,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1001,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 2.06, 'deg': 247, 'gust': 5.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 06:00:00'},
#   {'dt': 1705741200,
#    'main': {'temp': 262.75,
#     'feels_like': 258.05,
#     'temp_min': 262.75,
#     'temp_max': 262.75,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1001,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 22},
#    'wind': {'speed': 2.33, 'deg': 208, 'gust': 4.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 09:00:00'},
#   {'dt': 1705752000,
#    'main': {'temp': 264.3,
#     'feels_like': 258.54,
#     'temp_min': 264.3,
#     'temp_max': 264.3,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1000,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 3.44, 'deg': 162, 'gust': 9.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 12:00:00'},
#   {'dt': 1705762800,
#    'main': {'temp': 264.29,
#     'feels_like': 257.67,
#     'temp_min': 264.29,
#     'temp_max': 264.29,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1000,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.36, 'deg': 170, 'gust': 12.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 15:00:00'}],
#  'city': {'id': 524901,
#   'name': 'Moscow',
#   'coord': {'lat': 55.7522, 'lon': 37.6156},
#   'country': 'RU',
#   'population': 0,
#   'timezone': 10800,
#   'sunrise': 1705297807,
#   'sunset': 1705325208}}

# %%
API_KEY='3d7302197b47bf80fe9fd0542b0e51f8'
url ='http://api.openweathermap.org/data/2.5/forecast'
response = requests.get(url, params = {'id':524901, 'appid':API_KEY})
response.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1705341600,
#    'main': {'temp': 270.59,
#     'feels_like': 264.88,
#     'temp_min': 268.92,
#     'temp_max': 270.59,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 976,
#     'humidity': 94,
#     'temp_kf': 1.67},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.25, 'deg': 180, 'gust': 12.61},
#    'visibility': 273,
#    'pop': 0.32,
#    'snow': {'3h': 0.19},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-15 18:00:00'},
#   {'dt': 1705352400,
#    'main': {'temp': 270.15,
#     'feels_like': 263.98,
#     'temp_min': 269.27,
#     'temp_max': 270.15,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 975,
#     'humidity': 93,
#     'temp_kf': 0.88},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.84, 'deg': 187, 'gust': 13.45},
#    'visibility': 579,
#    'pop': 1,
#    'snow': {'3h': 0.38},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-15 21:00:00'},
#   {'dt': 1705363200,
#    'main': {'temp': 269.3,
#     'feels_like': 262.99,
#     'temp_min': 268.66,
#     'temp_max': 269.3,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 975,
#     'humidity': 92,
#     'temp_kf': 0.64},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.7, 'deg': 191, 'gust': 13.05},
#    'visibility': 8629,
#    'pop': 0.76,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 00:00:00'},
#   {'dt': 1705374000,
#    'main': {'temp': 268.47,
#     'feels_like': 262.12,
#     'temp_min': 268.47,
#     'temp_max': 268.47,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 975,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.4, 'deg': 192, 'gust': 13.22},
#    'visibility': 10000,
#    'pop': 0.26,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 03:00:00'},
#   {'dt': 1705384800,
#    'main': {'temp': 267.81,
#     'feels_like': 261.87,
#     'temp_min': 267.81,
#     'temp_max': 267.81,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 976,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.56, 'deg': 192, 'gust': 12.07},
#    'visibility': 10000,
#    'pop': 0.08,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-16 06:00:00'},
#   {'dt': 1705395600,
#    'main': {'temp': 268.4,
#     'feels_like': 263.1,
#     'temp_min': 268.4,
#     'temp_max': 268.4,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 976,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 3.91, 'deg': 180, 'gust': 10.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-16 09:00:00'},
#   {'dt': 1705406400,
#    'main': {'temp': 269.85,
#     'feels_like': 265.09,
#     'temp_min': 269.85,
#     'temp_max': 269.85,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 975,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 3.65, 'deg': 185, 'gust': 7.65},
#    'visibility': 8988,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-16 12:00:00'},
#   {'dt': 1705417200,
#    'main': {'temp': 269.51,
#     'feels_like': 264.74,
#     'temp_min': 269.51,
#     'temp_max': 269.51,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 974,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.58, 'deg': 200, 'gust': 7.55},
#    'visibility': 8168,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 15:00:00'},
#   {'dt': 1705428000,
#    'main': {'temp': 265.14,
#     'feels_like': 261.54,
#     'temp_min': 265.14,
#     'temp_max': 265.14,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 974,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.89, 'deg': 203, 'gust': 3.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 18:00:00'},
#   {'dt': 1705438800,
#    'main': {'temp': 262.14,
#     'feels_like': 257.04,
#     'temp_min': 262.14,
#     'temp_max': 262.14,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 975,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 2.53, 'deg': 219, 'gust': 7.39},
#    'visibility': 6969,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 21:00:00'},
#   {'dt': 1705449600,
#    'main': {'temp': 265.16,
#     'feels_like': 258.72,
#     'temp_min': 265.16,
#     'temp_max': 265.16,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 976,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 4.38, 'deg': 240, 'gust': 10.37},
#    'visibility': 3049,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 00:00:00'},
#   {'dt': 1705460400,
#    'main': {'temp': 264.54,
#     'feels_like': 257.56,
#     'temp_min': 264.54,
#     'temp_max': 264.54,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 978,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.87, 'deg': 256, 'gust': 11.38},
#    'visibility': 771,
#    'pop': 0.26,
#    'snow': {'3h': 0.22},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 03:00:00'},
#   {'dt': 1705471200,
#    'main': {'temp': 262.05,
#     'feels_like': 255.05,
#     'temp_min': 262.05,
#     'temp_max': 262.05,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 981,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.99, 'deg': 273, 'gust': 12.72},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 06:00:00'},
#   {'dt': 1705482000,
#    'main': {'temp': 261.15,
#     'feels_like': 254.15,
#     'temp_min': 261.15,
#     'temp_max': 261.15,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 985,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.14, 'deg': 265, 'gust': 12.15},
#    'visibility': 6357,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 09:00:00'},
#   {'dt': 1705492800,
#    'main': {'temp': 260.22,
#     'feels_like': 253.22,
#     'temp_min': 260.22,
#     'temp_max': 260.22,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 988,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6, 'deg': 267, 'gust': 12.2},
#    'visibility': 5883,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 12:00:00'},
#   {'dt': 1705503600,
#    'main': {'temp': 259.41,
#     'feels_like': 252.41,
#     'temp_min': 259.41,
#     'temp_max': 259.41,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 991,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.67, 'deg': 268, 'gust': 13.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 15:00:00'},
#   {'dt': 1705514400,
#    'main': {'temp': 259.06,
#     'feels_like': 252.06,
#     'temp_min': 259.06,
#     'temp_max': 259.06,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 994,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 4.65, 'deg': 262, 'gust': 13.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 18:00:00'},
#   {'dt': 1705525200,
#    'main': {'temp': 259.64,
#     'feels_like': 252.64,
#     'temp_min': 259.64,
#     'temp_max': 259.64,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 997,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 15},
#    'wind': {'speed': 4.05, 'deg': 245, 'gust': 11.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 21:00:00'},
#   {'dt': 1705536000,
#    'main': {'temp': 257.31,
#     'feels_like': 250.35,
#     'temp_min': 257.31,
#     'temp_max': 257.31,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 998,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 11},
#    'wind': {'speed': 3.2, 'deg': 225, 'gust': 10.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 00:00:00'},
#   {'dt': 1705546800,
#    'main': {'temp': 256.37,
#     'feels_like': 250.15,
#     'temp_min': 256.37,
#     'temp_max': 256.37,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 997,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 2.56, 'deg': 172, 'gust': 8.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 03:00:00'},
#   {'dt': 1705557600,
#    'main': {'temp': 261.28,
#     'feels_like': 254.28,
#     'temp_min': 261.28,
#     'temp_max': 261.28,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 995,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 4.8, 'deg': 157, 'gust': 16.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 06:00:00'},
#   {'dt': 1705568400,
#    'main': {'temp': 264.41,
#     'feels_like': 257.41,
#     'temp_min': 264.41,
#     'temp_max': 264.41,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 991,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.98, 'deg': 153, 'gust': 20.76},
#    'visibility': 5928,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 09:00:00'},
#   {'dt': 1705579200,
#    'main': {'temp': 265.9,
#     'feels_like': 258.9,
#     'temp_min': 265.9,
#     'temp_max': 265.9,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 985,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.12, 'deg': 157, 'gust': 20.83},
#    'visibility': 137,
#    'pop': 1,
#    'snow': {'3h': 2.95},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 12:00:00'},
#   {'dt': 1705590000,
#    'main': {'temp': 268.35,
#     'feels_like': 261.35,
#     'temp_min': 268.35,
#     'temp_max': 268.35,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 980,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.88, 'deg': 161, 'gust': 18},
#    'visibility': 147,
#    'pop': 1,
#    'snow': {'3h': 2.18},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 15:00:00'},
#   {'dt': 1705600800,
#    'main': {'temp': 272.93,
#     'feels_like': 267.22,
#     'temp_min': 272.93,
#     'temp_max': 272.93,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 976,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.42, 'deg': 173, 'gust': 15.95},
#    'visibility': 118,
#    'pop': 1,
#    'snow': {'3h': 2.44},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 18:00:00'},
#   {'dt': 1705611600,
#    'main': {'temp': 273.93,
#     'feels_like': 268.65,
#     'temp_min': 273.93,
#     'temp_max': 273.93,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 974,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.09, 'deg': 184, 'gust': 16.74},
#    'visibility': 61,
#    'pop': 1,
#    'snow': {'3h': 4.05},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 21:00:00'},
#   {'dt': 1705622400,
#    'main': {'temp': 274.61,
#     'feels_like': 269.62,
#     'temp_min': 274.61,
#     'temp_max': 274.61,
#     'pressure': 991,
#     'sea_level': 991,
#     'grnd_level': 973,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.85, 'deg': 200, 'gust': 15.05},
#    'visibility': 45,
#    'pop': 1,
#    'snow': {'3h': 1.94},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 00:00:00'},
#   {'dt': 1705633200,
#    'main': {'temp': 273.8,
#     'feels_like': 269.52,
#     'temp_min': 273.8,
#     'temp_max': 273.8,
#     'pressure': 991,
#     'sea_level': 991,
#     'grnd_level': 972,
#     'humidity': 99,
#     'temp_kf': 0},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.22, 'deg': 209, 'gust': 12.99},
#    'visibility': 30,
#    'pop': 1,
#    'snow': {'3h': 1.93},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 03:00:00'},
#   {'dt': 1705644000,
#    'main': {'temp': 273.84,
#     'feels_like': 269.75,
#     'temp_min': 273.84,
#     'temp_max': 273.84,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 974,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.95, 'deg': 238, 'gust': 9.55},
#    'visibility': 23,
#    'pop': 1,
#    'snow': {'3h': 1.18},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 06:00:00'},
#   {'dt': 1705654800,
#    'main': {'temp': 272.97,
#     'feels_like': 267.68,
#     'temp_min': 272.97,
#     'temp_max': 272.97,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 979,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.6, 'deg': 281, 'gust': 10.52},
#    'visibility': 10000,
#    'pop': 0.2,
#    'snow': {'3h': 0.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 09:00:00'},
#   {'dt': 1705665600,
#    'main': {'temp': 269.89,
#     'feels_like': 264.25,
#     'temp_min': 269.89,
#     'temp_max': 269.89,
#     'pressure': 1001,
#     'sea_level': 1001,
#     'grnd_level': 982,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 4.86, 'deg': 261, 'gust': 11.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 12:00:00'},
#   {'dt': 1705676400,
#    'main': {'temp': 267.72,
#     'feels_like': 261.6,
#     'temp_min': 267.72,
#     'temp_max': 267.72,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 987,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.78, 'deg': 260, 'gust': 11.8},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 15:00:00'},
#   {'dt': 1705687200,
#    'main': {'temp': 265.81,
#     'feels_like': 259.55,
#     'temp_min': 265.81,
#     'temp_max': 265.81,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 990,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.35, 'deg': 270, 'gust': 11.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 18:00:00'},
#   {'dt': 1705698000,
#    'main': {'temp': 264.07,
#     'feels_like': 257.98,
#     'temp_min': 264.07,
#     'temp_max': 264.07,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 993,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.72, 'deg': 269, 'gust': 10.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 21:00:00'},
#   {'dt': 1705708800,
#    'main': {'temp': 261.62,
#     'feels_like': 255.48,
#     'temp_min': 261.62,
#     'temp_max': 261.62,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 996,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 3.27, 'deg': 268, 'gust': 9.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 00:00:00'},
#   {'dt': 1705719600,
#    'main': {'temp': 259.33,
#     'feels_like': 253.67,
#     'temp_min': 259.33,
#     'temp_max': 259.33,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 998,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 2.56, 'deg': 274, 'gust': 7.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 03:00:00'},
#   {'dt': 1705730400,
#    'main': {'temp': 257.2,
#     'feels_like': 252,
#     'temp_min': 257.2,
#     'temp_max': 257.2,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1001,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 2.06, 'deg': 247, 'gust': 5.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 06:00:00'},
#   {'dt': 1705741200,
#    'main': {'temp': 262.75,
#     'feels_like': 258.05,
#     'temp_min': 262.75,
#     'temp_max': 262.75,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1001,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 22},
#    'wind': {'speed': 2.33, 'deg': 208, 'gust': 4.93},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 09:00:00'},
#   {'dt': 1705752000,
#    'main': {'temp': 264.3,
#     'feels_like': 258.54,
#     'temp_min': 264.3,
#     'temp_max': 264.3,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1000,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 47},
#    'wind': {'speed': 3.44, 'deg': 162, 'gust': 9.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 12:00:00'},
#   {'dt': 1705762800,
#    'main': {'temp': 264.29,
#     'feels_like': 257.67,
#     'temp_min': 264.29,
#     'temp_max': 264.29,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1000,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.36, 'deg': 170, 'gust': 12.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 15:00:00'}],
#  'city': {'id': 524901,
#   'name': 'Moscow',
#   'coord': {'lat': 55.7522, 'lon': 37.6156},
#   'country': 'RU',
#   'population': 0,
#   'timezone': 10800,
#   'sunrise': 1705297807,
#   'sunset': 1705325208}}

# %%
# Documentation: Call current weather data
# https://openweathermap.org/current#one
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}

# You need to specify latitude and longitude
# A Coruña: 'lat':43.372, 'lon':-8.3999

API_KEY='3d7302197b47bf80fe9fd0542b0e51f8'
url ='http://api.openweathermap.org/data/2.5/forecast'
response = requests.get(url, params = {'lat':43.372, 'lon':-8.3999,'appid':API_KEY})
response.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1705341600,
#    'main': {'temp': 288.43,
#     'feels_like': 288.21,
#     'temp_min': 286.72,
#     'temp_max': 288.43,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1009,
#     'humidity': 84,
#     'temp_kf': 1.71},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 20},
#    'wind': {'speed': 2.85, 'deg': 226, 'gust': 4.67},
#    'visibility': 10000,
#    'pop': 0.35,
#    'rain': {'3h': 0.2},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-15 18:00:00'},
#   {'dt': 1705352400,
#    'main': {'temp': 287.67,
#     'feels_like': 287.48,
#     'temp_min': 286.15,
#     'temp_max': 287.67,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1010,
#     'humidity': 88,
#     'temp_kf': 1.52},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 34},
#    'wind': {'speed': 3.08, 'deg': 204, 'gust': 5.85},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-15 21:00:00'},
#   {'dt': 1705363200,
#    'main': {'temp': 287.04,
#     'feels_like': 286.83,
#     'temp_min': 286.35,
#     'temp_max': 287.04,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 90,
#     'temp_kf': 0.69},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 60},
#    'wind': {'speed': 2.73, 'deg': 177, 'gust': 5.71},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 00:00:00'},
#   {'dt': 1705374000,
#    'main': {'temp': 286.54,
#     'feels_like': 286.36,
#     'temp_min': 286.54,
#     'temp_max': 286.54,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1007,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.11, 'deg': 178, 'gust': 4.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 03:00:00'},
#   {'dt': 1705384800,
#    'main': {'temp': 287.31,
#     'feels_like': 287.24,
#     'temp_min': 287.31,
#     'temp_max': 287.31,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1005,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.83, 'deg': 151, 'gust': 5.91},
#    'visibility': 10000,
#    'pop': 0.06,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 06:00:00'},
#   {'dt': 1705395600,
#    'main': {'temp': 288.18,
#     'feels_like': 288.19,
#     'temp_min': 288.18,
#     'temp_max': 288.18,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1003,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.23, 'deg': 162, 'gust': 10.97},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.63},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-16 09:00:00'},
#   {'dt': 1705406400,
#    'main': {'temp': 289.4,
#     'feels_like': 289.4,
#     'temp_min': 289.4,
#     'temp_max': 289.4,
#     'pressure': 1003,
#     'sea_level': 1003,
#     'grnd_level': 1001,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.96, 'deg': 194, 'gust': 15.35},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.65},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-16 12:00:00'},
#   {'dt': 1705417200,
#    'main': {'temp': 288.92,
#     'feels_like': 288.9,
#     'temp_min': 288.92,
#     'temp_max': 288.92,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 997,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.99, 'deg': 199, 'gust': 16.53},
#    'visibility': 10000,
#    'pop': 0.96,
#    'rain': {'3h': 1.3},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-16 15:00:00'},
#   {'dt': 1705428000,
#    'main': {'temp': 288.82,
#     'feels_like': 288.77,
#     'temp_min': 288.82,
#     'temp_max': 288.82,
#     'pressure': 998,
#     'sea_level': 998,
#     'grnd_level': 996,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.29, 'deg': 197, 'gust': 16.47},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.4},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 18:00:00'},
#   {'dt': 1705438800,
#    'main': {'temp': 289.15,
#     'feels_like': 289.05,
#     'temp_min': 289.15,
#     'temp_max': 289.15,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 994,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.24, 'deg': 200, 'gust': 20.81},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.35},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 21:00:00'},
#   {'dt': 1705449600,
#    'main': {'temp': 288.84,
#     'feels_like': 288.63,
#     'temp_min': 288.84,
#     'temp_max': 288.84,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 993,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.1, 'deg': 204, 'gust': 19.79},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.78},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 00:00:00'},
#   {'dt': 1705460400,
#    'main': {'temp': 288.19,
#     'feels_like': 287.81,
#     'temp_min': 288.19,
#     'temp_max': 288.19,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 991,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.21, 'deg': 208, 'gust': 18.05},
#    'visibility': 10000,
#    'pop': 0.18,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 03:00:00'},
#   {'dt': 1705471200,
#    'main': {'temp': 287.23,
#     'feels_like': 286.73,
#     'temp_min': 287.23,
#     'temp_max': 287.23,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 990,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 9.22, 'deg': 212, 'gust': 17.67},
#    'visibility': 10000,
#    'pop': 0.2,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 06:00:00'},
#   {'dt': 1705482000,
#    'main': {'temp': 286.83,
#     'feels_like': 286.29,
#     'temp_min': 286.83,
#     'temp_max': 286.83,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 991,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 8.3, 'deg': 211, 'gust': 15.92},
#    'visibility': 10000,
#    'pop': 0.6,
#    'rain': {'3h': 0.14},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 09:00:00'},
#   {'dt': 1705492800,
#    'main': {'temp': 286.43,
#     'feels_like': 286.14,
#     'temp_min': 286.43,
#     'temp_max': 286.43,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 990,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 8.8, 'deg': 207, 'gust': 17.44},
#    'visibility': 10000,
#    'pop': 0.84,
#    'rain': {'3h': 0.85},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 12:00:00'},
#   {'dt': 1705503600,
#    'main': {'temp': 286.71,
#     'feels_like': 286.37,
#     'temp_min': 286.71,
#     'temp_max': 286.71,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 990,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.42, 'deg': 221, 'gust': 17.56},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.31},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 15:00:00'},
#   {'dt': 1705514400,
#    'main': {'temp': 286.56,
#     'feels_like': 286.15,
#     'temp_min': 286.56,
#     'temp_max': 286.56,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 991,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.51, 'deg': 223, 'gust': 17.09},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.6},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 18:00:00'},
#   {'dt': 1705525200,
#    'main': {'temp': 286.39,
#     'feels_like': 285.83,
#     'temp_min': 286.39,
#     'temp_max': 286.39,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 993,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 10.31, 'deg': 221, 'gust': 18.66},
#    'visibility': 10000,
#    'pop': 0.75,
#    'rain': {'3h': 0.24},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 21:00:00'},
#   {'dt': 1705536000,
#    'main': {'temp': 286.37,
#     'feels_like': 285.81,
#     'temp_min': 286.37,
#     'temp_max': 286.37,
#     'pressure': 996,
#     'sea_level': 996,
#     'grnd_level': 994,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 78},
#    'wind': {'speed': 10.59, 'deg': 215, 'gust': 19.37},
#    'visibility': 10000,
#    'pop': 0.74,
#    'rain': {'3h': 0.19},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 00:00:00'},
#   {'dt': 1705546800,
#    'main': {'temp': 285.73,
#     'feels_like': 285.34,
#     'temp_min': 285.73,
#     'temp_max': 285.73,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 993,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 10.52, 'deg': 207, 'gust': 19.48},
#    'visibility': 10000,
#    'pop': 0.86,
#    'rain': {'3h': 1.17},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 03:00:00'},
#   {'dt': 1705557600,
#    'main': {'temp': 286.49,
#     'feels_like': 286.28,
#     'temp_min': 286.49,
#     'temp_max': 286.49,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 993,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 7.56, 'deg': 222, 'gust': 13.95},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 4.37},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 06:00:00'},
#   {'dt': 1705568400,
#    'main': {'temp': 284.79,
#     'feels_like': 284.44,
#     'temp_min': 284.79,
#     'temp_max': 284.79,
#     'pressure': 1000,
#     'sea_level': 1000,
#     'grnd_level': 998,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.8, 'deg': 15, 'gust': 10.87},
#    'visibility': 7341,
#    'pop': 0.98,
#    'rain': {'3h': 4.06},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 09:00:00'},
#   {'dt': 1705579200,
#    'main': {'temp': 282.6,
#     'feels_like': 279.37,
#     'temp_min': 282.6,
#     'temp_max': 282.6,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1006,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.03, 'deg': 15, 'gust': 9.19},
#    'visibility': 8076,
#    'pop': 1,
#    'rain': {'3h': 6.48},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 12:00:00'},
#   {'dt': 1705590000,
#    'main': {'temp': 281.82,
#     'feels_like': 278.55,
#     'temp_min': 281.82,
#     'temp_max': 281.82,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.46, 'deg': 33, 'gust': 8.6},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.46},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 15:00:00'},
#   {'dt': 1705600800,
#    'main': {'temp': 281.6,
#     'feels_like': 278.28,
#     'temp_min': 281.6,
#     'temp_max': 281.6,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1011,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.42, 'deg': 51, 'gust': 9.65},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.26},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 18:00:00'},
#   {'dt': 1705611600,
#    'main': {'temp': 281.58,
#     'feels_like': 278.02,
#     'temp_min': 281.58,
#     'temp_max': 281.58,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1012,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.17, 'deg': 56, 'gust': 10.83},
#    'visibility': 10000,
#    'pop': 0.31,
#    'rain': {'3h': 0.32},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 21:00:00'},
#   {'dt': 1705622400,
#    'main': {'temp': 281.16,
#     'feels_like': 277.49,
#     'temp_min': 281.16,
#     'temp_max': 281.16,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1012,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 7.12, 'deg': 65, 'gust': 11.21},
#    'visibility': 10000,
#    'pop': 0.02,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 00:00:00'},
#   {'dt': 1705633200,
#    'main': {'temp': 281.2,
#     'feels_like': 277.52,
#     'temp_min': 281.2,
#     'temp_max': 281.2,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1011,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 7.21, 'deg': 69, 'gust': 11.82},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 03:00:00'},
#   {'dt': 1705644000,
#    'main': {'temp': 281.52,
#     'feels_like': 277.65,
#     'temp_min': 281.52,
#     'temp_max': 281.52,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1011,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 8.19, 'deg': 72, 'gust': 12.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 06:00:00'},
#   {'dt': 1705654800,
#    'main': {'temp': 281.44,
#     'feels_like': 277.49,
#     'temp_min': 281.44,
#     'temp_max': 281.44,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1012,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 8.4, 'deg': 75, 'gust': 12.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 09:00:00'},
#   {'dt': 1705665600,
#    'main': {'temp': 282.91,
#     'feels_like': 279.64,
#     'temp_min': 282.91,
#     'temp_max': 282.91,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1013,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 7.49, 'deg': 66, 'gust': 10.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 12:00:00'},
#   {'dt': 1705676400,
#    'main': {'temp': 283.07,
#     'feels_like': 280.12,
#     'temp_min': 283.07,
#     'temp_max': 283.07,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1013,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 6.54, 'deg': 68, 'gust': 8.65},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 15:00:00'},
#   {'dt': 1705687200,
#    'main': {'temp': 280.11,
#     'feels_like': 277.01,
#     'temp_min': 280.11,
#     'temp_max': 280.11,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1015,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 4.83, 'deg': 71, 'gust': 6.33},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 18:00:00'},
#   {'dt': 1705698000,
#    'main': {'temp': 278.52,
#     'feels_like': 275.22,
#     'temp_min': 278.52,
#     'temp_max': 278.52,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1017,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.45, 'deg': 90, 'gust': 5.52},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 21:00:00'},
#   {'dt': 1705708800,
#    'main': {'temp': 277.71,
#     'feels_like': 275.4,
#     'temp_min': 277.71,
#     'temp_max': 277.71,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1017,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 2.65, 'deg': 139, 'gust': 3.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 00:00:00'},
#   {'dt': 1705719600,
#    'main': {'temp': 278.29,
#     'feels_like': 276.19,
#     'temp_min': 278.29,
#     'temp_max': 278.29,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1018,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.53, 'deg': 157, 'gust': 3.11},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 03:00:00'},
#   {'dt': 1705730400,
#    'main': {'temp': 278.86,
#     'feels_like': 276.48,
#     'temp_min': 278.86,
#     'temp_max': 278.86,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1018,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 3.04, 'deg': 164, 'gust': 4.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 06:00:00'},
#   {'dt': 1705741200,
#    'main': {'temp': 279.85,
#     'feels_like': 277.1,
#     'temp_min': 279.85,
#     'temp_max': 279.85,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1019,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 55},
#    'wind': {'speed': 3.99, 'deg': 191, 'gust': 8.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 09:00:00'},
#   {'dt': 1705752000,
#    'main': {'temp': 284.91,
#     'feels_like': 284.02,
#     'temp_min': 284.91,
#     'temp_max': 284.91,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1020,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 5.53, 'deg': 218, 'gust': 9.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 12:00:00'},
#   {'dt': 1705762800,
#    'main': {'temp': 285.21,
#     'feels_like': 284.3,
#     'temp_min': 285.21,
#     'temp_max': 285.21,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1018,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.99, 'deg': 206, 'gust': 10.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 15:00:00'}],
#  'city': {'id': 3119841,
#   'name': 'A Coruña',
#   'coord': {'lat': 43.372, 'lon': -8.3999},
#   'country': 'ES',
#   'population': 246056,
#   'timezone': 3600,
#   'sunrise': 1705305804,
#   'sunset': 1705339304}}

# %%
# PROPOSAL: use Geocoding API to obtain longitude and latitude.
# https://openweathermap.org/api/geocoding-api
# http://api.openweathermap.org/geo/1.0/direct?q={city name},{state code},{country code}&limit={limit}&appid={API key}

# %%
# http://api.openweathermap.org/geo/1.0/direct?q={city name},{state code},{country code}&limit={limit}&appid={API key}

# %% [markdown]
# To recap:
# - Query String Parameters to configure GET requests
# - Request Headers to configure GET requests
# - Authentication using parameters
# - Authentication using headers
