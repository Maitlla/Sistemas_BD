# %% [markdown]
# # Exercise 4. Bar plots.
# API SEABORN - Barplot
#
# https://seaborn.pydata.org/generated/seaborn.barplot.html

# %% [markdown]
# Para ir a la versión más actualizada de seaborn pero menos segura
#
# conda install seaborn -c conda-forge

# %%
# Imports the libraries needed to work with graphics

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import unicodedata

# %% [markdown]
# ### Laptops dataset
#
# 'Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price_euros'
#
# laptops.csv
#
# https://www.kaggle.com/ionaskel/laptop-prices

# %%
# 1.1 Load data and show an example
# Cargar datos y mostrar un ejemplo.

# %%
df_laptops = pd.read_csv('../datasets/laptops.csv', encoding = 'latin-1')
df_laptops.head()
# Out:
#    Unnamed: 0 Company      Product   TypeName  Inches  \
# 0           1   Apple  MacBook Pro  Ultrabook    13.3
# 1           2   Apple  Macbook Air  Ultrabook    13.3
# 2           3      HP       250 G6   Notebook    15.6
# 3           4   Apple  MacBook Pro  Ultrabook    15.4
# 4           5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# ...

# %%
df_laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df_laptops.describe()
# Out:
#         Unnamed: 0       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
# 1.2 Consult data types
# How many numeric/quantitative variables are there?
# How many categorical/qualitative variables?

# %%
# 1.2 Consultar tipos de datos
# ¿Cuántas variables numéricas/cuantitativas hay?
# ¿Cuántas variables categóricas/cualitativas?

# %%
#sns.barplot(data=df_laptops, x='',y='')

# %%
# 10 categorical variables
# 2 numerical variables
# 10 variables categóricas
# 2 variables numéricas

# %%
# 1.3 Consult the basic statistics of the dataset to get more information about the data.
# Consulta las estadísticas básicas del conjunto de datos para obtener más información sobre los datos.

# %%
# 1.4 You probably only consult the basic statistics of numerical variables. Do the same with the qualitative variables
# Probablemente sólo consultes las estadísticas básicas de variables numéricas. Haz lo mismo con las variables cualitativas.

# %%
# 1.5 With which categories could we make an analysis?
# In other words, is there any category that has few levels and that allows us to easily differentiate groups?
# 1.5 ¿Con qué categorías podríamos hacer un análisis?
# En otras palabras, ¿existe alguna categoría que tenga pocos niveles y que nos permita diferenciar grupos fácilmente?

# %%
# Some categories could be:
# - Company: 19 different companies
# - TypeName: 6 variations
# - RAM: 9 occurrences
# - OpSys: 9 occurrences

# %%
# Algunas categorías podrían ser:
# - Empresa: 19 empresas diferentes
# - TypeName: 6 variaciones
# - RAM: 9 apariciones
# - OpSys: 9 ocurrencias

# %%
# 1.6 Shows how the prices of laptops are **distributed**
# Muestra cómo se **distribuyen** los precios de las computadoras portátiles

# %%
# To represent the distribution of a single variable, without attending to categories, a histogram is sufficient.
# Para representar la distribución de una sola variable, sin atender a categorías, basta con un histograma.

# %%
# 1.7 What is the most expensive computer brand? 
# Think about what kind of graph you should display
# Adjust the graph to improve visualization
# Add a title

# %%
# 1.7 ¿Cuál es la marca de computadoras más cara?
# Piensa en qué tipo de gráfico deberías mostrar
# Ajustar el gráfico para mejorar la visualización.
# Añade un titulo

# %%
# 1.8 Check if there are significant differences in the price of laptops according to other categories.
# Comprueba si existen diferencias significativas en el precio de los portátiles según otras categorías.

# %%
# Do you think you now know more about the data in this dataset than you did at the beginning? ;-)
# ¿Crees que ahora saber más sobre los datos de este conjunto de datos que al principio?

# %% [markdown]
# ### Dataset about films
# 10k+ movies:  title, budget, revenue, cast, director, tagline, keywords, genres, release date, runtime etc.
#
# tmdb_movies_data.csv
#
# https://www.kaggle.com/juzershakir/tmdb-movies-dataset

# %%
# 2.1 Load the dataset and take a look
# Carga el conjunto de datos y eche un vistazo

# %%
df_movies = pd.read_csv('../datasets/tmdb_movies_data.csv')
df_movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df_movies.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
# 2.2 Which variables can be good as categories to classify the score of the films and display a bar chart?
# ¿Qué variables pueden servir como categorías para clasificar la puntuación de las películas y mostrar un gráfico de barras?

# %%
# 2.3 Shows the distribution of the average scores of the films.
# Do you recognize this graph?
# 2.3 Muestra la distribución de las puntuaciones medias de las películas.
# ¿Reconoces este gráfico?

# %%
# 2.4 Would you say that each year more or less films are made?
# ¿Dirías que cada año se hacen más o menos películas?

# %%
# 2.4 Classify films into short (<30 minutes), medium (<90) and long (>90).
# Are there differences in the average scores of the films in relation to their duration?
# 2.4 Clasificar las películas en corto (<30 minutos), medio (<90) y largo (>90).
# ¿Existen diferencias en las puntuaciones medias de las películas en relación a su duración?
