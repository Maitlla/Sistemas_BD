# %% [markdown]
# # APIs. Exercise 3

# %% [markdown]
# ### Geocoding and weather forecasting
# Geocoding: https://openweathermap.org/api/geocoding-api
#
# Forecasting: http://api.openweathermap.org/data/2.5/forecast

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Use the two APIs from openweathermap.org to query the forecast for a place you like
# 1. Use geocoding-api to get coordinates from the name of a place
# 2. Use forecast api to get the prediction to the given coordinates

# Utilice las dos API de openweathermap.org para consultar el pronóstico de un lugar que le guste
# 1. Utilice geocoding-api para obtener coordenadas del nombre de un lugar
# 2. Utilice la API de pronóstico para obtener la predicción en las coordenadas dadas.

# %%
# Documentacion: How to Start
# https://openweathermap.org/appid
API_KEY = os.getenv('API_KEY')
url ='http://api.openweathermap.org/data/2.5/forecast'
response = requests.get(url, params = {'id':524901, 'appid':API_KEY})
response.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1707987600,
#    'main': {'temp': 261.05,
#     'feels_like': 254.05,
#     'temp_min': 261.05,
#     'temp_max': 261.76,
#     'pressure': 1033,
#     'sea_level': 1033,
#     'grnd_level': 1014,
#     'humidity': 94,
#     'temp_kf': -0.71},
#    'weather': [{'id': 601,
#      'main': 'Snow',
#      'description': 'snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.84, 'deg': 130, 'gust': 13.88},
#    'visibility': 136,
#    'pop': 1,
#    'snow': {'3h': 3.01},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-15 09:00:00'},
#   {'dt': 1707998400,
#    'main': {'temp': 262.09,
#     'feels_like': 255.09,
#     'temp_min': 262.09,
#     'temp_max': 262.79,
#     'pressure': 1033,
#     'sea_level': 1033,
#     'grnd_level': 1014,
#     'humidity': 94,
#     'temp_kf': -0.7},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.29, 'deg': 132, 'gust': 10.69},
#    'visibility': 175,
#    'pop': 1,
#    'snow': {'3h': 0.84},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-15 12:00:00'},
#   {'dt': 1708009200,
#    'main': {'temp': 262.27,
#     'feels_like': 255.27,
#     'temp_min': 262.27,
#     'temp_max': 262.27,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1014,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.82, 'deg': 130, 'gust': 10.35},
#    'visibility': 166,
#    'pop': 0.98,
#    'snow': {'3h': 0.81},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-15 15:00:00'},
#   {'dt': 1708020000,
#    'main': {'temp': 262.14,
#     'feels_like': 255.14,
#     'temp_min': 262.14,
#     'temp_max': 262.14,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1014,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.29, 'deg': 134, 'gust': 10.11},
#    'visibility': 751,
#    'pop': 0.88,
#    'snow': {'3h': 0.4},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-15 18:00:00'},
#   {'dt': 1708030800,
#    'main': {'temp': 262.16,
#     'feels_like': 255.4,
#     'temp_min': 262.16,
#     'temp_max': 262.16,
#     'pressure': 1035,
#     'sea_level': 1035,
#     'grnd_level': 1015,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.96, 'deg': 135, 'gust': 9.26},
#    'visibility': 1046,
#    'pop': 0.32,
#    'snow': {'3h': 0.15},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-15 21:00:00'},
#   {'dt': 1708041600,
#    'main': {'temp': 262.27,
#     'feels_like': 255.73,
#     'temp_min': 262.27,
#     'temp_max': 262.27,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1015,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.77, 'deg': 135, 'gust': 8.8},
#    'visibility': 710,
#    'pop': 0.28,
#    'snow': {'3h': 0.12},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-16 00:00:00'},
#   {'dt': 1708052400,
#    'main': {'temp': 262.46,
#     'feels_like': 255.87,
#     'temp_min': 262.46,
#     'temp_max': 262.46,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1014,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.86, 'deg': 136, 'gust': 8.3},
#    'visibility': 745,
#    'pop': 0.2,
#    'snow': {'3h': 0.19},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-16 03:00:00'},
#   {'dt': 1708063200,
#    'main': {'temp': 262.82,
#     'feels_like': 256.35,
#     'temp_min': 262.82,
#     'temp_max': 262.82,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1014,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.82, 'deg': 137, 'gust': 8.15},
#    'visibility': 643,
#    'pop': 0.2,
#    'snow': {'3h': 0.15},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-16 06:00:00'},
#   {'dt': 1708074000,
#    'main': {'temp': 264.95,
#     'feels_like': 259.05,
#     'temp_min': 264.95,
#     'temp_max': 264.95,
#     'pressure': 1034,
#     'sea_level': 1034,
#     'grnd_level': 1014,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.72, 'deg': 145, 'gust': 6.54},
#    'visibility': 237,
#    'pop': 0.8,
#    'snow': {'3h': 0.53},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-16 09:00:00'},
#   {'dt': 1708084800,
#    'main': {'temp': 266.6,
#     'feels_like': 261,
#     'temp_min': 266.6,
#     'temp_max': 266.6,
#     'pressure': 1033,
#     'sea_level': 1033,
#     'grnd_level': 1013,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.79, 'deg': 141, 'gust': 6.71},
#    'visibility': 159,
#    'pop': 1,
#    'snow': {'3h': 1.13},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-16 12:00:00'},
#   {'dt': 1708095600,
#    'main': {'temp': 266.55,
#     'feels_like': 261.25,
#     'temp_min': 266.55,
#     'temp_max': 266.55,
#     'pressure': 1033,
#     'sea_level': 1033,
#     'grnd_level': 1013,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.46, 'deg': 142, 'gust': 7.67},
#    'visibility': 225,
#    'pop': 1,
#    'snow': {'3h': 0.88},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-16 15:00:00'},
#   {'dt': 1708106400,
#    'main': {'temp': 265.7,
#     'feels_like': 260.13,
#     'temp_min': 265.7,
#     'temp_max': 265.7,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1013,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.55, 'deg': 143, 'gust': 8.21},
#    'visibility': 495,
#    'pop': 1,
#    'snow': {'3h': 0.31},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-16 18:00:00'},
#   {'dt': 1708117200,
#    'main': {'temp': 265.09,
#     'feels_like': 259.76,
#     'temp_min': 265.09,
#     'temp_max': 265.09,
#     'pressure': 1032,
#     'sea_level': 1032,
#     'grnd_level': 1012,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.19, 'deg': 151, 'gust': 7.94},
#    'visibility': 622,
#    'pop': 0.2,
#    'snow': {'3h': 0.15},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-16 21:00:00'},
#   {'dt': 1708128000,
#    'main': {'temp': 265.22,
#     'feels_like': 259.82,
#     'temp_min': 265.22,
#     'temp_max': 265.22,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1012,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 3.28, 'deg': 157, 'gust': 8.17},
#    'visibility': 399,
#    'pop': 0.2,
#    'snow': {'3h': 0.22},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-17 00:00:00'},
#   {'dt': 1708138800,
#    'main': {'temp': 265.97,
#     'feels_like': 260.22,
#     'temp_min': 265.97,
#     'temp_max': 265.97,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1010,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.8, 'deg': 168, 'gust': 9.36},
#    'visibility': 285,
#    'pop': 0.61,
#    'snow': {'3h': 0.41},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-17 03:00:00'},
#   {'dt': 1708149600,
#    'main': {'temp': 265.99,
#     'feels_like': 259.83,
#     'temp_min': 265.99,
#     'temp_max': 265.99,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1009,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.28, 'deg': 178, 'gust': 11.38},
#    'visibility': 10000,
#    'pop': 0.6,
#    'snow': {'3h': 0.37},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-17 06:00:00'},
#   {'dt': 1708160400,
#    'main': {'temp': 268.55,
#     'feels_like': 262.72,
#     'temp_min': 268.55,
#     'temp_max': 268.55,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1008,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.65, 'deg': 184, 'gust': 11.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-17 09:00:00'},
#   {'dt': 1708171200,
#    'main': {'temp': 270.81,
#     'feels_like': 265.28,
#     'temp_min': 270.81,
#     'temp_max': 270.81,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1006,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.05, 'deg': 184, 'gust': 11.62},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-17 12:00:00'},
#   {'dt': 1708182000,
#    'main': {'temp': 270.91,
#     'feels_like': 265.37,
#     'temp_min': 270.91,
#     'temp_max': 270.91,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1005,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 5.1, 'deg': 189, 'gust': 11.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-17 15:00:00'},
#   {'dt': 1708192800,
#    'main': {'temp': 271.2,
#     'feels_like': 265.61,
#     'temp_min': 271.2,
#     'temp_max': 271.2,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1003,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 5.31, 'deg': 188, 'gust': 13.25},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-17 18:00:00'},
#   {'dt': 1708203600,
#    'main': {'temp': 269.15,
#     'feels_like': 263.36,
#     'temp_min': 269.15,
#     'temp_max': 269.15,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1002,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.81, 'deg': 196, 'gust': 13.84},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-17 21:00:00'},
#   {'dt': 1708214400,
#    'main': {'temp': 267.99,
#     'feels_like': 262.03,
#     'temp_min': 267.99,
#     'temp_max': 267.99,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1000,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 4.64, 'deg': 190, 'gust': 13.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-18 00:00:00'},
#   {'dt': 1708225200,
#    'main': {'temp': 270.51,
#     'feels_like': 265.1,
#     'temp_min': 270.51,
#     'temp_max': 270.51,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 998,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13n'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 4.74, 'deg': 205, 'gust': 13.25},
#    'visibility': 297,
#    'pop': 0.27,
#    'snow': {'3h': 0.16},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-18 03:00:00'},
#   {'dt': 1708236000,
#    'main': {'temp': 272.57,
#     'feels_like': 267.85,
#     'temp_min': 272.57,
#     'temp_max': 272.57,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 997,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 4.45, 'deg': 225, 'gust': 11.86},
#    'visibility': 674,
#    'pop': 0.82,
#    'snow': {'3h': 0.87},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-18 06:00:00'},
#   {'dt': 1708246800,
#    'main': {'temp': 272.14,
#     'feels_like': 266.71,
#     'temp_min': 272.14,
#     'temp_max': 272.14,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 999,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 600,
#      'main': 'Snow',
#      'description': 'light snow',
#      'icon': '13d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 5.46, 'deg': 299, 'gust': 9.44},
#    'visibility': 1648,
#    'pop': 0.84,
#    'snow': {'3h': 0.28},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-18 09:00:00'},
#   {'dt': 1708257600,
#    'main': {'temp': 271.35,
#     'feels_like': 266.11,
#     'temp_min': 271.35,
#     'temp_max': 271.35,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1000,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 4.8, 'deg': 304, 'gust': 7.57},
#    'visibility': 10000,
#    'pop': 0.43,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-18 12:00:00'},
#   {'dt': 1708268400,
#    'main': {'temp': 269.07,
#     'feels_like': 264.17,
#     'temp_min': 269.07,
#     'temp_max': 269.07,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1002,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.62, 'deg': 297, 'gust': 8.78},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-18 15:00:00'},
#   {'dt': 1708279200,
#    'main': {'temp': 263.56,
#     'feels_like': 258.32,
#     'temp_min': 263.56,
#     'temp_max': 263.56,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1004,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 2.84, 'deg': 273, 'gust': 8.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-18 18:00:00'},
#   {'dt': 1708290000,
#    'main': {'temp': 264.68,
#     'feels_like': 259.35,
#     'temp_min': 264.68,
#     'temp_max': 264.68,
#     'pressure': 1024,
#     'sea_level': 1024,
#     'grnd_level': 1004,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 91},
#    'wind': {'speed': 3.11, 'deg': 276, 'gust': 9.27},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-18 21:00:00'},
#   {'dt': 1708300800,
#    'main': {'temp': 261.08,
#     'feels_like': 255.32,
#     'temp_min': 261.08,
#     'temp_max': 261.08,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1006,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 67},
#    'wind': {'speed': 2.87, 'deg': 282, 'gust': 8.38},
#    'visibility': 6967,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-19 00:00:00'},
#   {'dt': 1708311600,
#    'main': {'temp': 258.02,
#     'feels_like': 252.05,
#     'temp_min': 258.02,
#     'temp_max': 258.02,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1007,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 62},
#    'wind': {'speed': 2.6, 'deg': 285, 'gust': 7.42},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-19 03:00:00'},
#   {'dt': 1708322400,
#    'main': {'temp': 258.48,
#     'feels_like': 253.16,
#     'temp_min': 258.48,
#     'temp_max': 258.48,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1009,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 2.25, 'deg': 291, 'gust': 7.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-19 06:00:00'},
#   {'dt': 1708333200,
#    'main': {'temp': 265.79,
#     'feels_like': 261.04,
#     'temp_min': 265.79,
#     'temp_max': 265.79,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1010,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 2.8, 'deg': 308, 'gust': 4.55},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-19 09:00:00'},
#   {'dt': 1708344000,
#    'main': {'temp': 267.98,
#     'feels_like': 264.26,
#     'temp_min': 267.98,
#     'temp_max': 267.98,
#     'pressure': 1029,
#     'sea_level': 1029,
#     'grnd_level': 1010,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 51},
#    'wind': {'speed': 2.3, 'deg': 309, 'gust': 3.56},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-19 12:00:00'},
#   {'dt': 1708354800,
#    'main': {'temp': 261.88,
#     'feels_like': 261.88,
#     'temp_min': 261.88,
#     'temp_max': 261.88,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1011,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.25, 'deg': 275, 'gust': 1.24},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-19 15:00:00'},
#   {'dt': 1708365600,
#    'main': {'temp': 256.84,
#     'feels_like': 256.84,
#     'temp_min': 256.84,
#     'temp_max': 256.84,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1011,
#     'humidity': 100,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.64, 'deg': 281, 'gust': 0.65},
#    'visibility': 6547,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-19 18:00:00'},
#   {'dt': 1708376400,
#    'main': {'temp': 258.55,
#     'feels_like': 258.55,
#     'temp_min': 258.55,
#     'temp_max': 258.55,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1011,
#     'humidity': 98,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 0.66, 'deg': 174, 'gust': 0.66},
#    'visibility': 6548,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-19 21:00:00'},
#   {'dt': 1708387200,
#    'main': {'temp': 261.94,
#     'feels_like': 258.61,
#     'temp_min': 261.94,
#     'temp_max': 261.94,
#     'pressure': 1031,
#     'sea_level': 1031,
#     'grnd_level': 1011,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.5, 'deg': 159, 'gust': 2.18},
#    'visibility': 6602,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-20 00:00:00'},
#   {'dt': 1708398000,
#    'main': {'temp': 262.92,
#     'feels_like': 259.4,
#     'temp_min': 262.92,
#     'temp_max': 262.92,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1010,
#     'humidity': 97,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.66, 'deg': 158, 'gust': 3.9},
#    'visibility': 6794,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-02-20 03:00:00'},
#   {'dt': 1708408800,
#    'main': {'temp': 264.39,
#     'feels_like': 260.73,
#     'temp_min': 264.39,
#     'temp_max': 264.39,
#     'pressure': 1030,
#     'sea_level': 1030,
#     'grnd_level': 1010,
#     'humidity': 96,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.86, 'deg': 162, 'gust': 4.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-02-20 06:00:00'}],
#  'city': {'id': 524901,
#   'name': 'Moscow',
#   'coord': {'lat': 55.7522, 'lon': 37.6156},
#   'country': 'RU',
#   'population': 0,
#   'timezone': 10800,
#   'sunrise': 1707972965,
#   'sunset': 1708007494}}

# %%
# Documentation: Call current weather data
# https://openweathermap.org/current#one
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}

# You need to specify latitude and longitude
# A Coruña: 'lat':43.372, 'lon':-8.3999

API_KEY='3d7302197b47bf80fe9fd0542b0e51f8'
url ='http://api.openweathermap.org/data/2.5/forecast'
response = requests.get(url, params = {'lat':43.372, 'lon':-8.3999,'appid':API_KEY})
response.json()
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1705438800,
#    'main': {'temp': 289.36,
#     'feels_like': 289.26,
#     'temp_min': 288.8,
#     'temp_max': 289.36,
#     'pressure': 994,
#     'sea_level': 994,
#     'grnd_level': 992,
#     'humidity': 85,
#     'temp_kf': 0.56},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 9.63, 'deg': 194, 'gust': 20.53},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 3.55},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-16 21:00:00'},
#   {'dt': 1705449600,
#    'main': {'temp': 289.03,
#     'feels_like': 288.87,
#     'temp_min': 288.72,
#     'temp_max': 289.03,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 991,
#     'humidity': 84,
#     'temp_kf': 0.31},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 9.71, 'deg': 208, 'gust': 18.89},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.75},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 00:00:00'},
#   {'dt': 1705460400,
#    'main': {'temp': 288.15,
#     'feels_like': 287.85,
#     'temp_min': 288.15,
#     'temp_max': 288.15,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 991,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.1, 'deg': 214, 'gust': 17.32},
#    'visibility': 10000,
#    'pop': 0.66,
#    'rain': {'3h': 0.2},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 03:00:00'},
#   {'dt': 1705471200,
#    'main': {'temp': 286.9,
#     'feels_like': 286.45,
#     'temp_min': 286.9,
#     'temp_max': 286.9,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 990,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 8.78, 'deg': 213, 'gust': 16.59},
#    'visibility': 10000,
#    'pop': 0.66,
#    'rain': {'3h': 0.14},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 06:00:00'},
#   {'dt': 1705482000,
#    'main': {'temp': 286.87,
#     'feels_like': 286.33,
#     'temp_min': 286.87,
#     'temp_max': 286.87,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 990,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 68},
#    'wind': {'speed': 8.51, 'deg': 201, 'gust': 17.35},
#    'visibility': 10000,
#    'pop': 0.42,
#    'rain': {'3h': 0.11},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 09:00:00'},
#   {'dt': 1705492800,
#    'main': {'temp': 286.78,
#     'feels_like': 286.52,
#     'temp_min': 286.78,
#     'temp_max': 286.78,
#     'pressure': 992,
#     'sea_level': 992,
#     'grnd_level': 989,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 9.91, 'deg': 212, 'gust': 18.4},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 3.08},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 12:00:00'},
#   {'dt': 1705503600,
#    'main': {'temp': 286.75,
#     'feels_like': 286.44,
#     'temp_min': 286.75,
#     'temp_max': 286.75,
#     'pressure': 991,
#     'sea_level': 991,
#     'grnd_level': 989,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.97, 'deg': 217, 'gust': 20.66},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.34},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-17 15:00:00'},
#   {'dt': 1705514400,
#    'main': {'temp': 286.47,
#     'feels_like': 286.18,
#     'temp_min': 286.47,
#     'temp_max': 286.47,
#     'pressure': 993,
#     'sea_level': 993,
#     'grnd_level': 991,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.91, 'deg': 226, 'gust': 19.12},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 4.41},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 18:00:00'},
#   {'dt': 1705525200,
#    'main': {'temp': 286.44,
#     'feels_like': 286.1,
#     'temp_min': 286.44,
#     'temp_max': 286.44,
#     'pressure': 995,
#     'sea_level': 995,
#     'grnd_level': 993,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.5, 'deg': 222, 'gust': 18.68},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.99},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-17 21:00:00'},
#   {'dt': 1705536000,
#    'main': {'temp': 286.43,
#     'feels_like': 286.01,
#     'temp_min': 286.43,
#     'temp_max': 286.43,
#     'pressure': 997,
#     'sea_level': 997,
#     'grnd_level': 995,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.85, 'deg': 220, 'gust': 18.33},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.71},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 00:00:00'},
#   {'dt': 1705546800,
#    'main': {'temp': 286.06,
#     'feels_like': 285.65,
#     'temp_min': 286.06,
#     'temp_max': 286.06,
#     'pressure': 998,
#     'sea_level': 998,
#     'grnd_level': 995,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 10.81, 'deg': 217, 'gust': 19.25},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.81},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 03:00:00'},
#   {'dt': 1705557600,
#    'main': {'temp': 286.27,
#     'feels_like': 285.83,
#     'temp_min': 286.27,
#     'temp_max': 286.27,
#     'pressure': 999,
#     'sea_level': 999,
#     'grnd_level': 996,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.44, 'deg': 210, 'gust': 16.69},
#    'visibility': 10000,
#    'pop': 0.92,
#    'rain': {'3h': 0.49},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 06:00:00'},
#   {'dt': 1705568400,
#    'main': {'temp': 286.03,
#     'feels_like': 285.75,
#     'temp_min': 286.03,
#     'temp_max': 286.03,
#     'pressure': 1002,
#     'sea_level': 1002,
#     'grnd_level': 1000,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.56, 'deg': 333, 'gust': 11.73},
#    'visibility': 10000,
#    'pop': 0.97,
#    'rain': {'3h': 1.88},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 09:00:00'},
#   {'dt': 1705579200,
#    'main': {'temp': 282.97,
#     'feels_like': 279.48,
#     'temp_min': 282.97,
#     'temp_max': 282.97,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1006,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.44, 'deg': 28, 'gust': 11.75},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 4.05},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 12:00:00'},
#   {'dt': 1705590000,
#    'main': {'temp': 282.03,
#     'feels_like': 278.55,
#     'temp_min': 282.03,
#     'temp_max': 282.03,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1008,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.34, 'deg': 36, 'gust': 9.91},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.14},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-18 15:00:00'},
#   {'dt': 1705600800,
#    'main': {'temp': 281.72,
#     'feels_like': 278.45,
#     'temp_min': 281.72,
#     'temp_max': 281.72,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.36, 'deg': 51, 'gust': 9.38},
#    'visibility': 10000,
#    'pop': 0.98,
#    'rain': {'3h': 0.8},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 18:00:00'},
#   {'dt': 1705611600,
#    'main': {'temp': 281.86,
#     'feels_like': 278.36,
#     'temp_min': 281.86,
#     'temp_max': 281.86,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1011,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.23, 'deg': 57, 'gust': 11.43},
#    'visibility': 10000,
#    'pop': 0.41,
#    'rain': {'3h': 0.36},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-18 21:00:00'},
#   {'dt': 1705622400,
#    'main': {'temp': 282.17,
#     'feels_like': 278.56,
#     'temp_min': 282.17,
#     'temp_max': 282.17,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 7.97, 'deg': 61, 'gust': 12.53},
#    'visibility': 10000,
#    'pop': 0.34,
#    'rain': {'3h': 0.24},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 00:00:00'},
#   {'dt': 1705633200,
#    'main': {'temp': 282.12,
#     'feels_like': 278.29,
#     'temp_min': 282.12,
#     'temp_max': 282.12,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 8.76, 'deg': 66, 'gust': 13.56},
#    'visibility': 10000,
#    'pop': 0.06,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 03:00:00'},
#   {'dt': 1705644000,
#    'main': {'temp': 282.24,
#     'feels_like': 278.27,
#     'temp_min': 282.24,
#     'temp_max': 282.24,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1008,
#     'humidity': 82,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.49, 'deg': 68, 'gust': 14.52},
#    'visibility': 10000,
#    'pop': 0.08,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 06:00:00'},
#   {'dt': 1705654800,
#    'main': {'temp': 282.09,
#     'feels_like': 277.96,
#     'temp_min': 282.09,
#     'temp_max': 282.09,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.99, 'deg': 65, 'gust': 15.44},
#    'visibility': 10000,
#    'pop': 0.07,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 09:00:00'},
#   {'dt': 1705665600,
#    'main': {'temp': 282.87,
#     'feels_like': 279.12,
#     'temp_min': 282.87,
#     'temp_max': 282.87,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 9.42, 'deg': 65, 'gust': 14.56},
#    'visibility': 10000,
#    'pop': 0.05,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 12:00:00'},
#   {'dt': 1705676400,
#    'main': {'temp': 282.57,
#     'feels_like': 278.83,
#     'temp_min': 282.57,
#     'temp_max': 282.57,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 8.96, 'deg': 66, 'gust': 13.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-19 15:00:00'},
#   {'dt': 1705687200,
#    'main': {'temp': 281.18,
#     'feels_like': 277.4,
#     'temp_min': 281.18,
#     'temp_max': 281.18,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 70},
#    'wind': {'speed': 7.51, 'deg': 73, 'gust': 12.58},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 18:00:00'},
#   {'dt': 1705698000,
#    'main': {'temp': 280.4,
#     'feels_like': 276.66,
#     'temp_min': 280.4,
#     'temp_max': 280.4,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1012,
#     'humidity': 78,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 6.68, 'deg': 64, 'gust': 10.38},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-19 21:00:00'},
#   {'dt': 1705708800,
#    'main': {'temp': 280.04,
#     'feels_like': 276.51,
#     'temp_min': 280.04,
#     'temp_max': 280.04,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1014,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 5.83, 'deg': 70, 'gust': 9.96},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 00:00:00'},
#   {'dt': 1705719600,
#    'main': {'temp': 279.58,
#     'feels_like': 276.65,
#     'temp_min': 279.58,
#     'temp_max': 279.58,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1014,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 4.22, 'deg': 87, 'gust': 6.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 03:00:00'},
#   {'dt': 1705730400,
#    'main': {'temp': 278.89,
#     'feels_like': 277,
#     'temp_min': 278.89,
#     'temp_max': 278.89,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1015,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 5},
#    'wind': {'speed': 2.41, 'deg': 109, 'gust': 2.79},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 06:00:00'},
#   {'dt': 1705741200,
#    'main': {'temp': 279.49,
#     'feels_like': 278.44,
#     'temp_min': 279.49,
#     'temp_max': 279.49,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1017,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.66, 'deg': 137, 'gust': 2.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 09:00:00'},
#   {'dt': 1705752000,
#    'main': {'temp': 284.02,
#     'feels_like': 282.96,
#     'temp_min': 284.02,
#     'temp_max': 284.02,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1018,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 0.36, 'deg': 200, 'gust': 1.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 12:00:00'},
#   {'dt': 1705762800,
#    'main': {'temp': 284.1,
#     'feels_like': 283.16,
#     'temp_min': 284.1,
#     'temp_max': 284.1,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1018,
#     'humidity': 73,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 61},
#    'wind': {'speed': 2.03, 'deg': 320, 'gust': 2.64},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-20 15:00:00'},
#   {'dt': 1705773600,
#    'main': {'temp': 282.21,
#     'feels_like': 282.21,
#     'temp_min': 282.21,
#     'temp_max': 282.21,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1021,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 73},
#    'wind': {'speed': 1.05, 'deg': 313, 'gust': 2.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 18:00:00'},
#   {'dt': 1705784400,
#    'main': {'temp': 281.67,
#     'feels_like': 281.67,
#     'temp_min': 281.67,
#     'temp_max': 281.67,
#     'pressure': 1025,
#     'sea_level': 1025,
#     'grnd_level': 1023,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 0.58, 'deg': 167, 'gust': 1.14},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-20 21:00:00'},
#   {'dt': 1705795200,
#    'main': {'temp': 281.51,
#     'feels_like': 280.84,
#     'temp_min': 281.51,
#     'temp_max': 281.51,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1024,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 1.58, 'deg': 192, 'gust': 1.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-21 00:00:00'},
#   {'dt': 1705806000,
#    'main': {'temp': 280.97,
#     'feels_like': 280.03,
#     'temp_min': 280.97,
#     'temp_max': 280.97,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1025,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 1.76, 'deg': 190, 'gust': 1.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-21 03:00:00'},
#   {'dt': 1705816800,
#    'main': {'temp': 280.42,
#     'feels_like': 278.39,
#     'temp_min': 280.42,
#     'temp_max': 280.42,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1025,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 48},
#    'wind': {'speed': 2.99, 'deg': 174, 'gust': 3.26},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-21 06:00:00'},
#   {'dt': 1705827600,
#    'main': {'temp': 280.72,
#     'feels_like': 278.07,
#     'temp_min': 280.72,
#     'temp_max': 280.72,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1025,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 4.19, 'deg': 163, 'gust': 6.34},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-21 09:00:00'},
#   {'dt': 1705838400,
#    'main': {'temp': 285.45,
#     'feels_like': 284.59,
#     'temp_min': 285.45,
#     'temp_max': 285.45,
#     'pressure': 1028,
#     'sea_level': 1028,
#     'grnd_level': 1025,
#     'humidity': 71,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 21},
#    'wind': {'speed': 4.13, 'deg': 186, 'gust': 8.22},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-21 12:00:00'},
#   {'dt': 1705849200,
#    'main': {'temp': 286.78,
#     'feels_like': 286.18,
#     'temp_min': 286.78,
#     'temp_max': 286.78,
#     'pressure': 1026,
#     'sea_level': 1026,
#     'grnd_level': 1024,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 6.34, 'deg': 204, 'gust': 12.21},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-01-21 15:00:00'},
#   {'dt': 1705860000,
#    'main': {'temp': 285.75,
#     'feels_like': 285.23,
#     'temp_min': 285.75,
#     'temp_max': 285.75,
#     'pressure': 1027,
#     'sea_level': 1027,
#     'grnd_level': 1025,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 6.92, 'deg': 200, 'gust': 14.23},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2024-01-21 18:00:00'}],
#  'city': {'id': 3119841,
#   'name': 'A Coruña',
#   'coord': {'lat': 43.371, 'lon': -8.3959},
#   'country': 'ES',
#   'population': 246056,
#   'timezone': 3600,
#   'sunrise': 1705392173,
#   'sunset': 1705425775}}

# %% [markdown]
# API weather
# https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}

# %% [markdown]
# API call
# http://api.openweathermap.org/geo/1.0/direct?q={city name},{state code},{country code}&limit={limit}&appid={API key}

# %% [markdown]
# Example of API call
# http://api.openweathermap.org/geo/1.0/direct?q=London&limit=5&appid={API key}

# %%
API_KEY='3d7302197b47bf80fe9fd0542b0e51f8'
url ='http://api.openweathermap.org/data/2.5/forecast'
response = requests.get(url, params = {'lat':43.372, 'lon':-8.3999,'appid':API_KEY})
response.json()

# %% [markdown]
# ## Cryptocurrencies
#
# **Help**: Use some free api, for example:
# - https://www.coinapi.io/
# - https://min-api.cryptocompare.com/
# - ...

# %%
# Speculation with cryptocurrencies
# Use an API to calculate how many euros you can get from the two bitcoins you found cleaning the sofa

# Especulación con criptomonedas
# Usa una API para calcular cuántos euros puedes sacar de los dos bitcoins que encontraste limpiando el sofá

# %%
# You can continue speculating
# Withdraw 20.000€ and invest the rest in Ethereum
# How many ethereum cryptocurrencies can you get?

# Puedes seguir especulando
# Retirar 20.000€ e invertir el resto en Ethereum
# ¿Cuántas criptomonedas ethereum puedes conseguir?
