# %% [markdown]
# ### API's. 2

# %%
import requests

# %% [markdown]
# To recap...
# - We connect to an ENDPOIND
# - We use GET method
# - We receive a RESPONSE
# - response has a STATUS
# - response has a CONTENT
# - response has a HEADERS

# %%
# QUERY STRING PARAMETERS

# Many times we have to send parameters to our GET requests.
# We can add the data as parameters as a dictionary

# %%
# Example of a search API for github repositories
url = 'https://api.github.com/search/repositories'
response = requests.get(url)

# %%
response.json()
# Out:
# {'message': 'Validation Failed',
#  'errors': [{'resource': 'Search', 'field': 'q', 'code': 'missing'}],
#  'documentation_url': 'https://docs.github.com/v3/search'}

# %%
# It doesn't work because it requires parameters
# We can navigate the API documentation to see what parameters we need
# Look at the response: https://docs.github.com/v3/search
# Search repositories
# https://docs.github.com/en/rest/reference/search#search-repositories
# https://docs.github.com/en/search-github/searching-on-github/searching-for-repositories

# %%
# We can search for repositories associated with a user name
response = requests.get(url,
                       params={'q': 'user:bigdatawirtz'})

# %%
response.json()
# Out:
# {'total_count': 21,
#  'incomplete_results': False,
#  'items': [{'id': 569748332,
#    'node_id': 'R_kgDOIfWrbA',
#    'name': 'escenarios',
#    'full_name': 'bigdatawirtz/escenarios',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/escenarios',
#    'description': 'Escenarios para realizar exercicios de big data',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/escenarios',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/deployments',
#    'created_at': '2022-11-23T14:23:52Z',
#    'updated_at': '2023-10-30T11:37:26Z',
#    'pushed_at': '2024-01-07T21:01:24Z',
#    'git_url': 'git://github.com/bigdatawirtz/escenarios.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/escenarios.git',
#    'clone_url': 'https://github.com/bigdatawirtz/escenarios.git',
#    'svn_url': 'https://github.com/bigdatawirtz/escenarios',
#    'homepage': None,
#    'size': 1219,
#    'stargazers_count': 2,
#    'watchers_count': 2,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 5,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 5,
#    'open_issues': 0,
#    'watchers': 2,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 469518990,
#    'node_id': 'R_kgDOG_xKjg',
#    'name': 'restaurantes',
#    'full_name': 'bigdatawirtz/restaurantes',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/restaurantes',
#    'description': 'Unha lista de restaurantes colaborativa',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/restaurantes',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/restaurantes/deployments',
#    'created_at': '2022-03-13T23:15:34Z',
#    'updated_at': '2022-03-16T22:36:27Z',
#    'pushed_at': '2022-03-18T22:30:31Z',
#    'git_url': 'git://github.com/bigdatawirtz/restaurantes.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/restaurantes.git',
#    'clone_url': 'https://github.com/bigdatawirtz/restaurantes.git',
#    'svn_url': 'https://github.com/bigdatawirtz/restaurantes',
#    'homepage': None,
#    'size': 65,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 11,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 11,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 724223300,
#    'node_id': 'R_kgDOKyrFRA',
#    'name': 'GIFTQuestions',
#    'full_name': 'bigdatawirtz/GIFTQuestions',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/GIFTQuestions',
#    'description': 'Questions in GIFT format',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/GIFTQuestions/deployments',
#    'created_at': '2023-11-27T16:39:14Z',
#    'updated_at': '2023-11-27T17:00:20Z',
#    'pushed_at': '2023-12-04T08:57:09Z',
#    'git_url': 'git://github.com/bigdatawirtz/GIFTQuestions.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/GIFTQuestions.git',
#    'clone_url': 'https://github.com/bigdatawirtz/GIFTQuestions.git',
#    'svn_url': 'https://github.com/bigdatawirtz/GIFTQuestions',
#    'homepage': None,
#    'size': 85,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 19,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 19,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 708532594,
#    'node_id': 'R_kgDOKjtZcg',
#    'name': 'basic-tools',
#    'full_name': 'bigdatawirtz/basic-tools',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/basic-tools',
#    'description': 'Basic tools',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/basic-tools',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/basic-tools/deployments',
#    'created_at': '2023-10-22T20:37:39Z',
#    'updated_at': '2023-10-22T20:37:40Z',
#    'pushed_at': '2024-01-08T22:15:04Z',
#    'git_url': 'git://github.com/bigdatawirtz/basic-tools.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/basic-tools.git',
#    'clone_url': 'https://github.com/bigdatawirtz/basic-tools.git',
#    'svn_url': 'https://github.com/bigdatawirtz/basic-tools',
#    'homepage': None,
#    'size': 621,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 589924786,
#    'node_id': 'R_kgDOIymJsg',
#    'name': 'neo4j-data',
#    'full_name': 'bigdatawirtz/neo4j-data',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/neo4j-data',
#    'description': 'Datos de exemplo para bases de datos de grafos',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/neo4j-data/deployments',
#    'created_at': '2023-01-17T09:08:00Z',
#    'updated_at': '2023-01-17T09:08:00Z',
#    'pushed_at': '2023-01-24T12:04:56Z',
#    'git_url': 'git://github.com/bigdatawirtz/neo4j-data.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/neo4j-data.git',
#    'clone_url': 'https://github.com/bigdatawirtz/neo4j-data.git',
#    'svn_url': 'https://github.com/bigdatawirtz/neo4j-data',
#    'homepage': None,
#    'size': 1,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 721765885,
#    'node_id': 'R_kgDOKwVF_Q',
#    'name': 'opendata-task',
#    'full_name': 'bigdatawirtz/opendata-task',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/opendata-task',
#    'description': 'Entrega a túa tarefa OpenData',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/opendata-task',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/opendata-task/deployments',
#    'created_at': '2023-11-21T18:20:50Z',
#    'updated_at': '2023-11-21T18:20:51Z',
#    'pushed_at': '2023-11-21T18:37:18Z',
#    'git_url': 'git://github.com/bigdatawirtz/opendata-task.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/opendata-task.git',
#    'clone_url': 'https://github.com/bigdatawirtz/opendata-task.git',
#    'svn_url': 'https://github.com/bigdatawirtz/opendata-task',
#    'homepage': None,
#    'size': 134,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 16,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 16,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 574432121,
#    'node_id': 'R_kgDOIj0jeQ',
#    'name': 'bigdata-aplicado-2022',
#    'full_name': 'bigdatawirtz/bigdata-aplicado-2022',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/bigdata-aplicado-2022',
#    'description': 'Big Data Aplicado 2022',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/bigdata-aplicado-2022/deployments',
#    'created_at': '2022-12-05T09:51:24Z',
#    'updated_at': '2022-12-05T10:11:29Z',
#    'pushed_at': '2022-12-05T14:25:35Z',
#    'git_url': 'git://github.com/bigdatawirtz/bigdata-aplicado-2022.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/bigdata-aplicado-2022.git',
#    'clone_url': 'https://github.com/bigdatawirtz/bigdata-aplicado-2022.git',
#    'svn_url': 'https://github.com/bigdatawirtz/bigdata-aplicado-2022',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 568877495,
#    'node_id': 'R_kgDOIehhtw',
#    'name': 'vagrant-apache-mariadb',
#    'full_name': 'bigdatawirtz/vagrant-apache-mariadb',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/vagrant-apache-mariadb',
#    'description': 'Un exemplo de vagrant box con Apache2 e MariaDB',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/vagrant-apache-mariadb/deployments',
#    'created_at': '2022-11-21T15:48:01Z',
#    'updated_at': '2022-11-21T16:18:05Z',
#    'pushed_at': '2022-11-21T16:21:02Z',
#    'git_url': 'git://github.com/bigdatawirtz/vagrant-apache-mariadb.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/vagrant-apache-mariadb.git',
#    'clone_url': 'https://github.com/bigdatawirtz/vagrant-apache-mariadb.git',
#    'svn_url': 'https://github.com/bigdatawirtz/vagrant-apache-mariadb',
#    'homepage': None,
#    'size': 17,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'HTML',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 605968973,
#    'node_id': 'R_kgDOJB5aTQ',
#    'name': 'devops-exercicio1',
#    'full_name': 'bigdatawirtz/devops-exercicio1',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
# ...
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/nubes',
#    'description': 'Un repositorio para crear unha nube de palabras',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/nubes',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/nubes/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/nubes/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/nubes/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/nubes/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/nubes/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/nubes/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/nubes/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/nubes/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/nubes/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/nubes/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/nubes/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/nubes/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/nubes/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/nubes/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/nubes/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/nubes/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/nubes/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/nubes/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/nubes/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/nubes/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/nubes/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/nubes/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/nubes/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/nubes/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/nubes/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/nubes/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/nubes/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/nubes/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/nubes/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/nubes/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/nubes/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/nubes/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/nubes/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/nubes/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/nubes/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/nubes/deployments',
#    'created_at': '2022-11-15T11:18:59Z',
#    'updated_at': '2022-11-15T11:34:23Z',
#    'pushed_at': '2022-11-15T13:01:01Z',
#    'git_url': 'git://github.com/bigdatawirtz/nubes.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/nubes.git',
#    'clone_url': 'https://github.com/bigdatawirtz/nubes.git',
#    'svn_url': 'https://github.com/bigdatawirtz/nubes',
#    'homepage': None,
#    'size': 188,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 438440173,
#    'node_id': 'R_kgDOGiIQ7Q',
#    'name': 'exemplo-web',
#    'full_name': 'bigdatawirtz/exemplo-web',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/exemplo-web',
#    'description': 'Web de exemplo para prácticas de scraping',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/exemplo-web/deployments',
#    'created_at': '2021-12-15T00:11:16Z',
#    'updated_at': '2021-12-19T11:33:18Z',
#    'pushed_at': '2021-12-19T11:33:15Z',
#    'git_url': 'git://github.com/bigdatawirtz/exemplo-web.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/exemplo-web.git',
#    'clone_url': 'https://github.com/bigdatawirtz/exemplo-web.git',
#    'svn_url': 'https://github.com/bigdatawirtz/exemplo-web',
#    'homepage': None,
#    'size': 5089,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 591903335,
#    'node_id': 'R_kgDOI0e6Zw',
#    'name': 'pyactions',
#    'full_name': 'bigdatawirtz/pyactions',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/pyactions',
#    'description': 'Git Actions con python',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/pyactions',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/pyactions/deployments',
#    'created_at': '2023-01-22T09:39:02Z',
#    'updated_at': '2023-01-22T09:42:19Z',
#    'pushed_at': '2023-01-22T10:04:39Z',
#    'git_url': 'git://github.com/bigdatawirtz/pyactions.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/pyactions.git',
#    'clone_url': 'https://github.com/bigdatawirtz/pyactions.git',
#    'svn_url': 'https://github.com/bigdatawirtz/pyactions',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0}]}

# %%
# You have to identify the format of the answer to access data
# Number of answers?
response.json()['total_count']
# Out:
# 21

# %%
# Access the first element
response.json()['items'][0]
# Out:
# {'id': 569748332,
#  'node_id': 'R_kgDOIfWrbA',
#  'name': 'escenarios',
#  'full_name': 'bigdatawirtz/escenarios',
#  'private': False,
#  'owner': {'login': 'bigdatawirtz',
#   'id': 91669798,
#   'node_id': 'U_kgDOBXbFJg',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/bigdatawirtz',
#   'html_url': 'https://github.com/bigdatawirtz',
#   'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#   'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#   'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#   'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#   'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#   'type': 'User',
#   'site_admin': False},
#  'html_url': 'https://github.com/bigdatawirtz/escenarios',
#  'description': 'Escenarios para realizar exercicios de big data',
#  'fork': False,
#  'url': 'https://api.github.com/repos/bigdatawirtz/escenarios',
#  'forks_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/forks',
#  'keys_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/teams',
#  'hooks_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/hooks',
#  'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/events',
#  'assignees_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/tags',
#  'blobs_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/languages',
#  'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/stargazers',
#  'contributors_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/contributors',
#  'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/subscribers',
#  'subscription_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/subscription',
#  'commits_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/merges',
#  'archive_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/downloads',
#  'issues_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/deployments',
#  'created_at': '2022-11-23T14:23:52Z',
#  'updated_at': '2023-10-30T11:37:26Z',
#  'pushed_at': '2024-01-07T21:01:24Z',
#  'git_url': 'git://github.com/bigdatawirtz/escenarios.git',
#  'ssh_url': 'git@github.com:bigdatawirtz/escenarios.git',
#  'clone_url': 'https://github.com/bigdatawirtz/escenarios.git',
#  'svn_url': 'https://github.com/bigdatawirtz/escenarios',
#  'homepage': None,
#  'size': 1219,
#  'stargazers_count': 2,
#  'watchers_count': 2,
#  'language': 'Jupyter Notebook',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'has_discussions': False,
#  'forks_count': 5,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 0,
#  'license': {'key': 'gpl-3.0',
#   'name': 'GNU General Public License v3.0',
#   'spdx_id': 'GPL-3.0',
#   'url': 'https://api.github.com/licenses/gpl-3.0',
#   'node_id': 'MDc6TGljZW5zZTk='},
#  'allow_forking': True,
#  'is_template': False,
#  'web_commit_signoff_required': False,
#  'topics': [],
#  'visibility': 'public',
#  'forks': 5,
#  'open_issues': 0,
#  'watchers': 2,
#  'default_branch': 'main',
#  'score': 1.0}

# %%
response.json()['items']
# Out:
# [{'id': 569748332,
#   'node_id': 'R_kgDOIfWrbA',
#   'name': 'escenarios',
#   'full_name': 'bigdatawirtz/escenarios',
#   'private': False,
#   'owner': {'login': 'bigdatawirtz',
#    'id': 91669798,
#    'node_id': 'U_kgDOBXbFJg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bigdatawirtz',
#    'html_url': 'https://github.com/bigdatawirtz',
#    'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#    'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#    'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#    'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#    'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/bigdatawirtz/escenarios',
#   'description': 'Escenarios para realizar exercicios de big data',
#   'fork': False,
#   'url': 'https://api.github.com/repos/bigdatawirtz/escenarios',
#   'forks_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/forks',
#   'keys_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/teams',
#   'hooks_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/hooks',
#   'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/events',
#   'assignees_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/tags',
#   'blobs_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/languages',
#   'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/stargazers',
#   'contributors_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/contributors',
#   'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/subscribers',
#   'subscription_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/subscription',
#   'commits_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/merges',
#   'archive_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/downloads',
#   'issues_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/deployments',
#   'created_at': '2022-11-23T14:23:52Z',
#   'updated_at': '2023-10-30T11:37:26Z',
#   'pushed_at': '2024-01-07T21:01:24Z',
#   'git_url': 'git://github.com/bigdatawirtz/escenarios.git',
#   'ssh_url': 'git@github.com:bigdatawirtz/escenarios.git',
#   'clone_url': 'https://github.com/bigdatawirtz/escenarios.git',
#   'svn_url': 'https://github.com/bigdatawirtz/escenarios',
#   'homepage': None,
#   'size': 1219,
#   'stargazers_count': 2,
#   'watchers_count': 2,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 5,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'gpl-3.0',
#    'name': 'GNU General Public License v3.0',
#    'spdx_id': 'GPL-3.0',
#    'url': 'https://api.github.com/licenses/gpl-3.0',
#    'node_id': 'MDc6TGljZW5zZTk='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 5,
#   'open_issues': 0,
#   'watchers': 2,
#   'default_branch': 'main',
#   'score': 1.0}]

# %%
response.json()['items'][0]['owner']['id']
# Out:
# 91669798

# %%
# Access to the first repository name
response.json()['items'][0]['name']
# Out:
# 'escenarios'

# %%
# We can add several parameters according to the documentation.
# for example: limit the number of results
response = requests.get(url,
                       params={'q': 'user:bigdatawirtz','per_page':'1'})
response.json()
# Out:
# {'total_count': 21,
#  'incomplete_results': False,
#  'items': [{'id': 569748332,
#    'node_id': 'R_kgDOIfWrbA',
#    'name': 'escenarios',
#    'full_name': 'bigdatawirtz/escenarios',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/escenarios',
#    'description': 'Escenarios para realizar exercicios de big data',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/escenarios',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/escenarios/deployments',
#    'created_at': '2022-11-23T14:23:52Z',
#    'updated_at': '2023-10-30T11:37:26Z',
#    'pushed_at': '2024-01-07T21:01:24Z',
#    'git_url': 'git://github.com/bigdatawirtz/escenarios.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/escenarios.git',
#    'clone_url': 'https://github.com/bigdatawirtz/escenarios.git',
#    'svn_url': 'https://github.com/bigdatawirtz/escenarios',
#    'homepage': None,
#    'size': 1219,
#    'stargazers_count': 2,
#    'watchers_count': 2,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 5,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 5,
#    'open_issues': 0,
#    'watchers': 2,
#    'default_branch': 'main',
#    'score': 1.0}]}

# %%
# We can search for repositories that contain a word in their name    params={'q': 'Sistemas-bd-2023 in:name'})
response = requests.get(url,
                       params={'q': 'sistemas-bigdata in:name'})
response.json()
# Out:
# {'total_count': 5,
#  'incomplete_results': False,
#  'items': [{'id': 430857606,
#    'node_id': 'R_kgDOGa5dhg',
#    'name': 'sistemas-bigdata',
#    'full_name': 'gunter443/sistemas-bigdata',
#    'private': False,
#    'owner': {'login': 'gunter443',
#     'id': 74923961,
#     'node_id': 'MDQ6VXNlcjc0OTIzOTYx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/74923961?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/gunter443',
#     'html_url': 'https://github.com/gunter443',
#     'followers_url': 'https://api.github.com/users/gunter443/followers',
#     'following_url': 'https://api.github.com/users/gunter443/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/gunter443/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/gunter443/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/gunter443/subscriptions',
#     'organizations_url': 'https://api.github.com/users/gunter443/orgs',
#     'repos_url': 'https://api.github.com/users/gunter443/repos',
#     'events_url': 'https://api.github.com/users/gunter443/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/gunter443/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/gunter443/sistemas-bigdata',
#    'description': 'Repo de apoio para as clases do módulo de Sistemas Big Data',
#    'fork': False,
#    'url': 'https://api.github.com/repos/gunter443/sistemas-bigdata',
#    'forks_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/forks',
#    'keys_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/teams',
#    'hooks_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/hooks',
#    'issue_events_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/events',
#    'assignees_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/tags',
#    'blobs_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/languages',
#    'stargazers_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/stargazers',
#    'contributors_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/contributors',
#    'subscribers_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/subscribers',
#    'subscription_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/subscription',
#    'commits_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/merges',
#    'archive_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/downloads',
#    'issues_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/gunter443/sistemas-bigdata/deployments',
#    'created_at': '2021-11-22T20:37:02Z',
#    'updated_at': '2022-03-20T21:54:30Z',
#    'pushed_at': '2022-03-20T21:54:37Z',
#    'git_url': 'git://github.com/gunter443/sistemas-bigdata.git',
#    'ssh_url': 'git@github.com:gunter443/sistemas-bigdata.git',
#    'clone_url': 'https://github.com/gunter443/sistemas-bigdata.git',
#    'svn_url': 'https://github.com/gunter443/sistemas-bigdata',
#    'homepage': None,
#    'size': 47078,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 15,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 15,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 704316921,
#    'node_id': 'R_kgDOKfsF-Q',
#    'name': 'Bigdata_sistemas',
#    'full_name': 'ianq1w1/Bigdata_sistemas',
#    'private': False,
#    'owner': {'login': 'ianq1w1',
#     'id': 105610821,
#     'node_id': 'U_kgDOBkt-RQ',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/105610821?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ianq1w1',
#     'html_url': 'https://github.com/ianq1w1',
#     'followers_url': 'https://api.github.com/users/ianq1w1/followers',
#     'following_url': 'https://api.github.com/users/ianq1w1/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/ianq1w1/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/ianq1w1/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/ianq1w1/subscriptions',
#     'organizations_url': 'https://api.github.com/users/ianq1w1/orgs',
#     'repos_url': 'https://api.github.com/users/ianq1w1/repos',
#     'events_url': 'https://api.github.com/users/ianq1w1/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/ianq1w1/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/ianq1w1/Bigdata_sistemas',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas',
#    'forks_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/forks',
#    'keys_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/teams',
#    'hooks_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/hooks',
#    'issue_events_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/events',
#    'assignees_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/tags',
#    'blobs_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/languages',
#    'stargazers_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/stargazers',
#    'contributors_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/contributors',
#    'subscribers_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/subscribers',
#    'subscription_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/subscription',
#    'commits_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/merges',
#    'archive_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/downloads',
#    'issues_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/ianq1w1/Bigdata_sistemas/deployments',
#    'created_at': '2023-10-13T02:19:50Z',
#    'updated_at': '2023-10-14T01:02:52Z',
#    'pushed_at': '2023-10-31T18:37:04Z',
#    'git_url': 'git://github.com/ianq1w1/Bigdata_sistemas.git',
#    'ssh_url': 'git@github.com:ianq1w1/Bigdata_sistemas.git',
#    'clone_url': 'https://github.com/ianq1w1/Bigdata_sistemas.git',
#    'svn_url': 'https://github.com/ianq1w1/Bigdata_sistemas',
#    'homepage': None,
#    'size': 32,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 591004168,
#    'node_id': 'R_kgDOIzoCCA',
#    'name': 'sistemas-bigdata-2022',
#    'full_name': 'J-oken/sistemas-bigdata-2022',
#    'private': False,
#    'owner': {'login': 'J-oken',
#     'id': 118474932,
#     'node_id': 'U_kgDOBw_ItA',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/118474932?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/J-oken',
#     'html_url': 'https://github.com/J-oken',
#     'followers_url': 'https://api.github.com/users/J-oken/followers',
#     'following_url': 'https://api.github.com/users/J-oken/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/J-oken/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/J-oken/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/J-oken/subscriptions',
#     'organizations_url': 'https://api.github.com/users/J-oken/orgs',
#     'repos_url': 'https://api.github.com/users/J-oken/repos',
#     'events_url': 'https://api.github.com/users/J-oken/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/J-oken/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/J-oken/sistemas-bigdata-2022',
#    'description': 'Sistemas de Big Data',
#    'fork': False,
#    'url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022',
#    'forks_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/forks',
#    'keys_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/teams',
#    'hooks_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/hooks',
#    'issue_events_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/events',
#    'assignees_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/tags',
#    'blobs_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/languages',
#    'stargazers_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/stargazers',
#    'contributors_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/contributors',
#    'subscribers_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/subscribers',
#    'subscription_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/subscription',
#    'commits_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/merges',
#    'archive_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/downloads',
#    'issues_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/J-oken/sistemas-bigdata-2022/deployments',
#    'created_at': '2023-01-19T17:59:51Z',
#    'updated_at': '2023-01-19T18:03:24Z',
#    'pushed_at': '2023-01-19T18:03:18Z',
#    'git_url': 'git://github.com/J-oken/sistemas-bigdata-2022.git',
#    'ssh_url': 'git@github.com:J-oken/sistemas-bigdata-2022.git',
#    'clone_url': 'https://github.com/J-oken/sistemas-bigdata-2022.git',
#    'svn_url': 'https://github.com/J-oken/sistemas-bigdata-2022',
#    'homepage': None,
#    'size': 15029,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 725087312,
#    'node_id': 'R_kgDOKzf0UA',
#    'name': 'sistemas-bigdata-2023',
#    'full_name': 'bigdatawirtz/sistemas-bigdata-2023',
#    'private': False,
#    'owner': {'login': 'bigdatawirtz',
#     'id': 91669798,
#     'node_id': 'U_kgDOBXbFJg',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/91669798?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/bigdatawirtz',
#     'html_url': 'https://github.com/bigdatawirtz',
#     'followers_url': 'https://api.github.com/users/bigdatawirtz/followers',
#     'following_url': 'https://api.github.com/users/bigdatawirtz/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/bigdatawirtz/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/bigdatawirtz/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/bigdatawirtz/subscriptions',
#     'organizations_url': 'https://api.github.com/users/bigdatawirtz/orgs',
#     'repos_url': 'https://api.github.com/users/bigdatawirtz/repos',
#     'events_url': 'https://api.github.com/users/bigdatawirtz/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/bigdatawirtz/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/bigdatawirtz/sistemas-bigdata-2023',
#    'description': 'sistemas-bigdata-2023',
#    'fork': False,
#    'url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023',
#    'forks_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/forks',
#    'keys_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/teams',
#    'hooks_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/hooks',
#    'issue_events_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/events',
#    'assignees_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/tags',
#    'blobs_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/languages',
#    'stargazers_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/stargazers',
#    'contributors_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/contributors',
#    'subscribers_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/subscribers',
#    'subscription_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/subscription',
#    'commits_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/merges',
#    'archive_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/downloads',
#    'issues_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/bigdatawirtz/sistemas-bigdata-2023/deployments',
#    'created_at': '2023-11-29T12:12:41Z',
#    'updated_at': '2023-11-29T15:08:09Z',
#    'pushed_at': '2024-01-09T13:30:07Z',
#    'git_url': 'git://github.com/bigdatawirtz/sistemas-bigdata-2023.git',
#    'ssh_url': 'git@github.com:bigdatawirtz/sistemas-bigdata-2023.git',
#    'clone_url': 'https://github.com/bigdatawirtz/sistemas-bigdata-2023.git',
#    'svn_url': 'https://github.com/bigdatawirtz/sistemas-bigdata-2023',
#    'homepage': None,
#    'size': 14973,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0},
#   {'id': 432377091,
#    'node_id': 'R_kgDOGcWNAw',
#    'name': 'sistemas_recomendacion_bigdata_ueb',
#    'full_name': 'JSVargasQ/sistemas_recomendacion_bigdata_ueb',
#    'private': False,
#    'owner': {'login': 'JSVargasQ',
#     'id': 42383191,
#     'node_id': 'MDQ6VXNlcjQyMzgzMTkx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/42383191?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/JSVargasQ',
#     'html_url': 'https://github.com/JSVargasQ',
#     'followers_url': 'https://api.github.com/users/JSVargasQ/followers',
#     'following_url': 'https://api.github.com/users/JSVargasQ/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/JSVargasQ/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/JSVargasQ/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/JSVargasQ/subscriptions',
#     'organizations_url': 'https://api.github.com/users/JSVargasQ/orgs',
#     'repos_url': 'https://api.github.com/users/JSVargasQ/repos',
#     'events_url': 'https://api.github.com/users/JSVargasQ/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/JSVargasQ/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/JSVargasQ/sistemas_recomendacion_bigdata_ueb',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb',
#    'forks_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/forks',
#    'keys_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/teams',
#    'hooks_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/hooks',
#    'issue_events_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/events',
#    'assignees_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/tags',
#    'blobs_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/languages',
#    'stargazers_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/stargazers',
#    'contributors_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/contributors',
#    'subscribers_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/subscribers',
#    'subscription_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/subscription',
#    'commits_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/merges',
#    'archive_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/downloads',
#    'issues_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/JSVargasQ/sistemas_recomendacion_bigdata_ueb/deployments',
#    'created_at': '2021-11-27T05:31:03Z',
#    'updated_at': '2021-12-06T16:21:23Z',
#    'pushed_at': '2021-12-04T03:11:13Z',
#    'git_url': 'git://github.com/JSVargasQ/sistemas_recomendacion_bigdata_ueb.git',
#    'ssh_url': 'git@github.com:JSVargasQ/sistemas_recomendacion_bigdata_ueb.git',
#    'clone_url': 'https://github.com/JSVargasQ/sistemas_recomendacion_bigdata_ueb.git',
#    'svn_url': 'https://github.com/JSVargasQ/sistemas_recomendacion_bigdata_ueb',
#    'homepage': None,
#    'size': 3480,
#    'stargazers_count': 0,
#    'watchers_count': 0,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 0,
#    'default_branch': 'main',
#    'score': 1.0}]}

# %%
# We can search for repositories that contain a word in their name
response = requests.get(url,
                       params={'q': 'bigdata in:name'})
response.json()
# Out:
# {'total_count': 39955,
#  'incomplete_results': True,
#  'items': [{'id': 215028549,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTUwMjg1NDk=',
#    'name': 'bigData',
#    'full_name': 'hyh1750522171/bigData',
#    'private': False,
#    'owner': {'login': 'hyh1750522171',
#     'id': 35066516,
#     'node_id': 'MDQ6VXNlcjM1MDY2NTE2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/35066516?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/hyh1750522171',
#     'html_url': 'https://github.com/hyh1750522171',
#     'followers_url': 'https://api.github.com/users/hyh1750522171/followers',
#     'following_url': 'https://api.github.com/users/hyh1750522171/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/hyh1750522171/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/hyh1750522171/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/hyh1750522171/subscriptions',
#     'organizations_url': 'https://api.github.com/users/hyh1750522171/orgs',
#     'repos_url': 'https://api.github.com/users/hyh1750522171/repos',
#     'events_url': 'https://api.github.com/users/hyh1750522171/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/hyh1750522171/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/hyh1750522171/bigData',
#    'description': '大数据比赛项目库',
#    'fork': False,
#    'url': 'https://api.github.com/repos/hyh1750522171/bigData',
#    'forks_url': 'https://api.github.com/repos/hyh1750522171/bigData/forks',
#    'keys_url': 'https://api.github.com/repos/hyh1750522171/bigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/hyh1750522171/bigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/hyh1750522171/bigData/teams',
#    'hooks_url': 'https://api.github.com/repos/hyh1750522171/bigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/hyh1750522171/bigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/hyh1750522171/bigData/events',
#    'assignees_url': 'https://api.github.com/repos/hyh1750522171/bigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/hyh1750522171/bigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/hyh1750522171/bigData/tags',
#    'blobs_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/hyh1750522171/bigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/hyh1750522171/bigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/hyh1750522171/bigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/hyh1750522171/bigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/hyh1750522171/bigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/hyh1750522171/bigData/subscription',
#    'commits_url': 'https://api.github.com/repos/hyh1750522171/bigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/hyh1750522171/bigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/hyh1750522171/bigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/hyh1750522171/bigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/hyh1750522171/bigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/hyh1750522171/bigData/merges',
#    'archive_url': 'https://api.github.com/repos/hyh1750522171/bigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/hyh1750522171/bigData/downloads',
#    'issues_url': 'https://api.github.com/repos/hyh1750522171/bigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/hyh1750522171/bigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/hyh1750522171/bigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/hyh1750522171/bigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/hyh1750522171/bigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/hyh1750522171/bigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/hyh1750522171/bigData/deployments',
#    'created_at': '2019-10-14T11:41:48Z',
#    'updated_at': '2024-01-05T09:42:22Z',
#    'pushed_at': '2023-02-17T02:29:42Z',
#    'git_url': 'git://github.com/hyh1750522171/bigData.git',
#    'ssh_url': 'git@github.com:hyh1750522171/bigData.git',
#    'clone_url': 'https://github.com/hyh1750522171/bigData.git',
#    'svn_url': 'https://github.com/hyh1750522171/bigData',
#    'homepage': None,
#    'size': 28619,
#    'stargazers_count': 663,
#    'watchers_count': 663,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 545,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': None,
#    'allow_forking': True,
#    'is_template': True,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 545,
#    'open_issues': 2,
#    'watchers': 663,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 74181851,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk3NDE4MTg1MQ==',
#    'name': 'BigData',
#    'full_name': 'monsonlee/BigData',
#    'private': False,
#    'owner': {'login': 'monsonlee',
#     'id': 17783047,
#     'node_id': 'MDQ6VXNlcjE3NzgzMDQ3',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/17783047?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/monsonlee',
#     'html_url': 'https://github.com/monsonlee',
#     'followers_url': 'https://api.github.com/users/monsonlee/followers',
#     'following_url': 'https://api.github.com/users/monsonlee/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/monsonlee/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/monsonlee/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/monsonlee/subscriptions',
#     'organizations_url': 'https://api.github.com/users/monsonlee/orgs',
#     'repos_url': 'https://api.github.com/users/monsonlee/repos',
#     'events_url': 'https://api.github.com/users/monsonlee/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/monsonlee/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/monsonlee/BigData',
#    'description': 'BigData Project 大数据项目由浅入深',
#    'fork': False,
#    'url': 'https://api.github.com/repos/monsonlee/BigData',
#    'forks_url': 'https://api.github.com/repos/monsonlee/BigData/forks',
#    'keys_url': 'https://api.github.com/repos/monsonlee/BigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/monsonlee/BigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/monsonlee/BigData/teams',
#    'hooks_url': 'https://api.github.com/repos/monsonlee/BigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/monsonlee/BigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/monsonlee/BigData/events',
#    'assignees_url': 'https://api.github.com/repos/monsonlee/BigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/monsonlee/BigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/monsonlee/BigData/tags',
#    'blobs_url': 'https://api.github.com/repos/monsonlee/BigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/monsonlee/BigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/monsonlee/BigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/monsonlee/BigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/monsonlee/BigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/monsonlee/BigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/monsonlee/BigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/monsonlee/BigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/monsonlee/BigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/monsonlee/BigData/subscription',
#    'commits_url': 'https://api.github.com/repos/monsonlee/BigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/monsonlee/BigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/monsonlee/BigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/monsonlee/BigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/monsonlee/BigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/monsonlee/BigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/monsonlee/BigData/merges',
#    'archive_url': 'https://api.github.com/repos/monsonlee/BigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/monsonlee/BigData/downloads',
#    'issues_url': 'https://api.github.com/repos/monsonlee/BigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/monsonlee/BigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/monsonlee/BigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/monsonlee/BigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/monsonlee/BigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/monsonlee/BigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/monsonlee/BigData/deployments',
#    'created_at': '2016-11-19T02:25:14Z',
#    'updated_at': '2024-01-09T23:31:58Z',
#    'pushed_at': '2017-11-30T08:33:11Z',
#    'git_url': 'git://github.com/monsonlee/BigData.git',
#    'ssh_url': 'git@github.com:monsonlee/BigData.git',
#    'clone_url': 'https://github.com/monsonlee/BigData.git',
#    'svn_url': 'https://github.com/monsonlee/BigData',
#    'homepage': '',
#    'size': 1494,
#    'stargazers_count': 619,
#    'watchers_count': 619,
#    'language': 'Java',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 292,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 292,
#    'open_issues': 2,
#    'watchers': 619,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 140367143,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNDAzNjcxNDM=',
#    'name': 'BigData',
#    'full_name': 'sunnyandgood/BigData',
#    'private': False,
#    'owner': {'login': 'sunnyandgood',
#     'id': 33865475,
#     'node_id': 'MDQ6VXNlcjMzODY1NDc1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/33865475?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sunnyandgood',
#     'html_url': 'https://github.com/sunnyandgood',
#     'followers_url': 'https://api.github.com/users/sunnyandgood/followers',
#     'following_url': 'https://api.github.com/users/sunnyandgood/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sunnyandgood/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sunnyandgood/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sunnyandgood/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sunnyandgood/orgs',
#     'repos_url': 'https://api.github.com/users/sunnyandgood/repos',
#     'events_url': 'https://api.github.com/users/sunnyandgood/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sunnyandgood/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/sunnyandgood/BigData',
#    'description': '💎🔥大数据学习笔记',
#    'fork': False,
#    'url': 'https://api.github.com/repos/sunnyandgood/BigData',
#    'forks_url': 'https://api.github.com/repos/sunnyandgood/BigData/forks',
#    'keys_url': 'https://api.github.com/repos/sunnyandgood/BigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sunnyandgood/BigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sunnyandgood/BigData/teams',
#    'hooks_url': 'https://api.github.com/repos/sunnyandgood/BigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sunnyandgood/BigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sunnyandgood/BigData/events',
#    'assignees_url': 'https://api.github.com/repos/sunnyandgood/BigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sunnyandgood/BigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sunnyandgood/BigData/tags',
#    'blobs_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sunnyandgood/BigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sunnyandgood/BigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/sunnyandgood/BigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sunnyandgood/BigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sunnyandgood/BigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sunnyandgood/BigData/subscription',
#    'commits_url': 'https://api.github.com/repos/sunnyandgood/BigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sunnyandgood/BigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sunnyandgood/BigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sunnyandgood/BigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sunnyandgood/BigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sunnyandgood/BigData/merges',
#    'archive_url': 'https://api.github.com/repos/sunnyandgood/BigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sunnyandgood/BigData/downloads',
#    'issues_url': 'https://api.github.com/repos/sunnyandgood/BigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sunnyandgood/BigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sunnyandgood/BigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sunnyandgood/BigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sunnyandgood/BigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sunnyandgood/BigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sunnyandgood/BigData/deployments',
#    'created_at': '2018-07-10T02:37:47Z',
#    'updated_at': '2024-01-08T01:33:51Z',
#    'pushed_at': '2019-05-13T12:04:24Z',
#    'git_url': 'git://github.com/sunnyandgood/BigData.git',
#    'ssh_url': 'git@github.com:sunnyandgood/BigData.git',
#    'clone_url': 'https://github.com/sunnyandgood/BigData.git',
#    'svn_url': 'https://github.com/sunnyandgood/BigData',
#    'homepage': '',
#    'size': 331418,
#    'stargazers_count': 658,
#    'watchers_count': 658,
#    'language': 'Java',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 224,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['flume',
#     'hadoop',
#     'hbase',
#     'hdfs',
#     'hive',
#     'linux',
#     'mapreduce',
#     'mysql',
#     'shell',
#     'sqoop',
#     'zookeeper'],
#    'visibility': 'public',
#    'forks': 224,
#    'open_issues': 2,
#    'watchers': 658,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 57103571,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk1NzEwMzU3MQ==',
#    'name': 'BigData',
#    'full_name': 'minsuk-heo/BigData',
#    'private': False,
#    'owner': {'login': 'minsuk-heo',
#     'id': 14434896,
#     'node_id': 'MDQ6VXNlcjE0NDM0ODk2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/14434896?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/minsuk-heo',
#     'html_url': 'https://github.com/minsuk-heo',
#     'followers_url': 'https://api.github.com/users/minsuk-heo/followers',
#     'following_url': 'https://api.github.com/users/minsuk-heo/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/minsuk-heo/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/minsuk-heo/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/minsuk-heo/subscriptions',
#     'organizations_url': 'https://api.github.com/users/minsuk-heo/orgs',
#     'repos_url': 'https://api.github.com/users/minsuk-heo/repos',
#     'events_url': 'https://api.github.com/users/minsuk-heo/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/minsuk-heo/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/minsuk-heo/BigData',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/minsuk-heo/BigData',
#    'forks_url': 'https://api.github.com/repos/minsuk-heo/BigData/forks',
#    'keys_url': 'https://api.github.com/repos/minsuk-heo/BigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/minsuk-heo/BigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/minsuk-heo/BigData/teams',
#    'hooks_url': 'https://api.github.com/repos/minsuk-heo/BigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/minsuk-heo/BigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/minsuk-heo/BigData/events',
#    'assignees_url': 'https://api.github.com/repos/minsuk-heo/BigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/minsuk-heo/BigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/minsuk-heo/BigData/tags',
#    'blobs_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/minsuk-heo/BigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/minsuk-heo/BigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/minsuk-heo/BigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/minsuk-heo/BigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/minsuk-heo/BigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/minsuk-heo/BigData/subscription',
#    'commits_url': 'https://api.github.com/repos/minsuk-heo/BigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/minsuk-heo/BigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/minsuk-heo/BigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/minsuk-heo/BigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/minsuk-heo/BigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/minsuk-heo/BigData/merges',
#    'archive_url': 'https://api.github.com/repos/minsuk-heo/BigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/minsuk-heo/BigData/downloads',
#    'issues_url': 'https://api.github.com/repos/minsuk-heo/BigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/minsuk-heo/BigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/minsuk-heo/BigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/minsuk-heo/BigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/minsuk-heo/BigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/minsuk-heo/BigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/minsuk-heo/BigData/deployments',
#    'created_at': '2016-04-26T06:27:16Z',
#    'updated_at': '2024-01-10T16:13:31Z',
#    'pushed_at': '2021-01-03T06:55:58Z',
#    'git_url': 'git://github.com/minsuk-heo/BigData.git',
#    'ssh_url': 'git@github.com:minsuk-heo/BigData.git',
#    'clone_url': 'https://github.com/minsuk-heo/BigData.git',
#    'svn_url': 'https://github.com/minsuk-heo/BigData',
#    'homepage': None,
#    'size': 63,
#    'stargazers_count': 164,
#    'watchers_count': 164,
#    'language': 'Shell',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 243,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 243,
#    'open_issues': 1,
#    'watchers': 164,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 43791031,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0Mzc5MTAzMQ==',
#    'name': 'bigdata',
#    'full_name': 'haifengl/bigdata',
#    'private': False,
#    'owner': {'login': 'haifengl',
#     'id': 5502052,
#     'node_id': 'MDQ6VXNlcjU1MDIwNTI=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/5502052?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/haifengl',
#     'html_url': 'https://github.com/haifengl',
#     'followers_url': 'https://api.github.com/users/haifengl/followers',
#     'following_url': 'https://api.github.com/users/haifengl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/haifengl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/haifengl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/haifengl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/haifengl/orgs',
#     'repos_url': 'https://api.github.com/users/haifengl/repos',
#     'events_url': 'https://api.github.com/users/haifengl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/haifengl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/haifengl/bigdata',
#    'description': 'Introduction to Big Data',
#    'fork': False,
#    'url': 'https://api.github.com/repos/haifengl/bigdata',
#    'forks_url': 'https://api.github.com/repos/haifengl/bigdata/forks',
#    'keys_url': 'https://api.github.com/repos/haifengl/bigdata/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/haifengl/bigdata/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/haifengl/bigdata/teams',
#    'hooks_url': 'https://api.github.com/repos/haifengl/bigdata/hooks',
#    'issue_events_url': 'https://api.github.com/repos/haifengl/bigdata/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/haifengl/bigdata/events',
#    'assignees_url': 'https://api.github.com/repos/haifengl/bigdata/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/haifengl/bigdata/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/haifengl/bigdata/tags',
#    'blobs_url': 'https://api.github.com/repos/haifengl/bigdata/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/haifengl/bigdata/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/haifengl/bigdata/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/haifengl/bigdata/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/haifengl/bigdata/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/haifengl/bigdata/languages',
#    'stargazers_url': 'https://api.github.com/repos/haifengl/bigdata/stargazers',
#    'contributors_url': 'https://api.github.com/repos/haifengl/bigdata/contributors',
#    'subscribers_url': 'https://api.github.com/repos/haifengl/bigdata/subscribers',
#    'subscription_url': 'https://api.github.com/repos/haifengl/bigdata/subscription',
#    'commits_url': 'https://api.github.com/repos/haifengl/bigdata/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/haifengl/bigdata/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/haifengl/bigdata/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/haifengl/bigdata/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/haifengl/bigdata/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/haifengl/bigdata/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/haifengl/bigdata/merges',
#    'archive_url': 'https://api.github.com/repos/haifengl/bigdata/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/haifengl/bigdata/downloads',
#    'issues_url': 'https://api.github.com/repos/haifengl/bigdata/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/haifengl/bigdata/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/haifengl/bigdata/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/haifengl/bigdata/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/haifengl/bigdata/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/haifengl/bigdata/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/haifengl/bigdata/deployments',
#    'created_at': '2015-10-07T02:34:22Z',
#    'updated_at': '2024-01-01T16:50:10Z',
#    'pushed_at': '2019-11-20T15:01:02Z',
#    'git_url': 'git://github.com/haifengl/bigdata.git',
#    'ssh_url': 'git@github.com:haifengl/bigdata.git',
#    'clone_url': 'https://github.com/haifengl/bigdata.git',
#    'svn_url': 'https://github.com/haifengl/bigdata',
#    'homepage': None,
#    'size': 3384,
#    'stargazers_count': 389,
#    'watchers_count': 389,
#    'language': 'TeX',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 150,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-2.0',
#     'name': 'GNU General Public License v2.0',
#     'spdx_id': 'GPL-2.0',
#     'url': 'https://api.github.com/licenses/gpl-2.0',
#     'node_id': 'MDc6TGljZW5zZTg='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 150,
#    'open_issues': 0,
#    'watchers': 389,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 48668182,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0ODY2ODE4Mg==',
#    'name': 'bigdata',
#    'full_name': 'mattshma/bigdata',
#    'private': False,
#    'owner': {'login': 'mattshma',
#     'id': 3884630,
#     'node_id': 'MDQ6VXNlcjM4ODQ2MzA=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/3884630?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/mattshma',
#     'html_url': 'https://github.com/mattshma',
#     'followers_url': 'https://api.github.com/users/mattshma/followers',
#     'following_url': 'https://api.github.com/users/mattshma/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/mattshma/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/mattshma/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/mattshma/subscriptions',
#     'organizations_url': 'https://api.github.com/users/mattshma/orgs',
#     'repos_url': 'https://api.github.com/users/mattshma/repos',
#     'events_url': 'https://api.github.com/users/mattshma/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/mattshma/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/mattshma/bigdata',
#    'description': 'hadoop,hbase,storm,spark,etc..',
#    'fork': False,
#    'url': 'https://api.github.com/repos/mattshma/bigdata',
#    'forks_url': 'https://api.github.com/repos/mattshma/bigdata/forks',
#    'keys_url': 'https://api.github.com/repos/mattshma/bigdata/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/mattshma/bigdata/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/mattshma/bigdata/teams',
#    'hooks_url': 'https://api.github.com/repos/mattshma/bigdata/hooks',
#    'issue_events_url': 'https://api.github.com/repos/mattshma/bigdata/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/mattshma/bigdata/events',
#    'assignees_url': 'https://api.github.com/repos/mattshma/bigdata/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/mattshma/bigdata/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/mattshma/bigdata/tags',
#    'blobs_url': 'https://api.github.com/repos/mattshma/bigdata/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/mattshma/bigdata/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/mattshma/bigdata/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/mattshma/bigdata/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/mattshma/bigdata/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/mattshma/bigdata/languages',
#    'stargazers_url': 'https://api.github.com/repos/mattshma/bigdata/stargazers',
#    'contributors_url': 'https://api.github.com/repos/mattshma/bigdata/contributors',
#    'subscribers_url': 'https://api.github.com/repos/mattshma/bigdata/subscribers',
#    'subscription_url': 'https://api.github.com/repos/mattshma/bigdata/subscription',
#    'commits_url': 'https://api.github.com/repos/mattshma/bigdata/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/mattshma/bigdata/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/mattshma/bigdata/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/mattshma/bigdata/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/mattshma/bigdata/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/mattshma/bigdata/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/mattshma/bigdata/merges',
#    'archive_url': 'https://api.github.com/repos/mattshma/bigdata/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/mattshma/bigdata/downloads',
#    'issues_url': 'https://api.github.com/repos/mattshma/bigdata/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/mattshma/bigdata/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/mattshma/bigdata/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/mattshma/bigdata/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/mattshma/bigdata/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/mattshma/bigdata/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/mattshma/bigdata/deployments',
#    'created_at': '2015-12-28T01:47:49Z',
#    'updated_at': '2024-01-09T13:14:10Z',
#    'pushed_at': '2019-11-25T08:17:38Z',
#    'git_url': 'git://github.com/mattshma/bigdata.git',
#    'ssh_url': 'git@github.com:mattshma/bigdata.git',
#    'clone_url': 'https://github.com/mattshma/bigdata.git',
#    'svn_url': 'https://github.com/mattshma/bigdata',
#    'homepage': None,
#    'size': 7512,
#    'stargazers_count': 160,
#    'watchers_count': 160,
#    'language': 'Shell',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 79,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 20,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 79,
#    'open_issues': 20,
#    'watchers': 160,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 138894231,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxMzg4OTQyMzE=',
#    'name': 'Bigdata',
#    'full_name': 'baolibin/Bigdata',
#    'private': False,
#    'owner': {'login': 'baolibin',
#     'id': 16797951,
#     'node_id': 'MDQ6VXNlcjE2Nzk3OTUx',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/16797951?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/baolibin',
#     'html_url': 'https://github.com/baolibin',
#     'followers_url': 'https://api.github.com/users/baolibin/followers',
#     'following_url': 'https://api.github.com/users/baolibin/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/baolibin/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/baolibin/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/baolibin/subscriptions',
#     'organizations_url': 'https://api.github.com/users/baolibin/orgs',
#     'repos_url': 'https://api.github.com/users/baolibin/repos',
#     'events_url': 'https://api.github.com/users/baolibin/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/baolibin/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/baolibin/Bigdata',
#    'description': '大数据处理相关技术学习之路(持续更新中...)。        Bigdata整理  -->  慢慢滴~ 大数据相关技术包括离线处理，实时处理，OLAP等，如hadoop、spark、flink、hive、hbase、oozie...以及大数据项目，如用户画像、数据仓库等，欢迎感兴趣的小伙伴一起来开发...',
#    'fork': False,
#    'url': 'https://api.github.com/repos/baolibin/Bigdata',
#    'forks_url': 'https://api.github.com/repos/baolibin/Bigdata/forks',
#    'keys_url': 'https://api.github.com/repos/baolibin/Bigdata/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/baolibin/Bigdata/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/baolibin/Bigdata/teams',
#    'hooks_url': 'https://api.github.com/repos/baolibin/Bigdata/hooks',
#    'issue_events_url': 'https://api.github.com/repos/baolibin/Bigdata/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/baolibin/Bigdata/events',
#    'assignees_url': 'https://api.github.com/repos/baolibin/Bigdata/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/baolibin/Bigdata/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/baolibin/Bigdata/tags',
#    'blobs_url': 'https://api.github.com/repos/baolibin/Bigdata/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/baolibin/Bigdata/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/baolibin/Bigdata/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/baolibin/Bigdata/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/baolibin/Bigdata/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/baolibin/Bigdata/languages',
#    'stargazers_url': 'https://api.github.com/repos/baolibin/Bigdata/stargazers',
#    'contributors_url': 'https://api.github.com/repos/baolibin/Bigdata/contributors',
#    'subscribers_url': 'https://api.github.com/repos/baolibin/Bigdata/subscribers',
#    'subscription_url': 'https://api.github.com/repos/baolibin/Bigdata/subscription',
#    'commits_url': 'https://api.github.com/repos/baolibin/Bigdata/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/baolibin/Bigdata/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/baolibin/Bigdata/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/baolibin/Bigdata/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/baolibin/Bigdata/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/baolibin/Bigdata/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/baolibin/Bigdata/merges',
#    'archive_url': 'https://api.github.com/repos/baolibin/Bigdata/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/baolibin/Bigdata/downloads',
#    'issues_url': 'https://api.github.com/repos/baolibin/Bigdata/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/baolibin/Bigdata/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/baolibin/Bigdata/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/baolibin/Bigdata/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/baolibin/Bigdata/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/baolibin/Bigdata/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/baolibin/Bigdata/deployments',
#    'created_at': '2018-06-27T14:38:59Z',
#    'updated_at': '2024-01-10T06:18:55Z',
#    'pushed_at': '2024-01-09T11:13:35Z',
#    'git_url': 'git://github.com/baolibin/Bigdata.git',
#    'ssh_url': 'git@github.com:baolibin/Bigdata.git',
#    'clone_url': 'https://github.com/baolibin/Bigdata.git',
#    'svn_url': 'https://github.com/baolibin/Bigdata',
#    'homepage': 'http://github.libin.io/bigdata',
#    'size': 7789,
#    'stargazers_count': 217,
#    'watchers_count': 217,
#    'language': 'Scala',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 55,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 10,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 55,
#    'open_issues': 10,
#    'watchers': 217,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 8681416,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk4NjgxNDE2',
#    'name': 'BigData',
#    'full_name': 'zwqjsj0404/BigData',
#    'private': False,
#    'owner': {'login': 'zwqjsj0404',
#     'id': 2196282,
#     'node_id': 'MDQ6VXNlcjIxOTYyODI=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/2196282?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/zwqjsj0404',
#     'html_url': 'https://github.com/zwqjsj0404',
#     'followers_url': 'https://api.github.com/users/zwqjsj0404/followers',
#     'following_url': 'https://api.github.com/users/zwqjsj0404/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/zwqjsj0404/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/zwqjsj0404/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/zwqjsj0404/subscriptions',
#     'organizations_url': 'https://api.github.com/users/zwqjsj0404/orgs',
#     'repos_url': 'https://api.github.com/users/zwqjsj0404/repos',
#     'events_url': 'https://api.github.com/users/zwqjsj0404/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/zwqjsj0404/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/zwqjsj0404/BigData',
#    'description': 'big data books and papers',
#    'fork': False,
#    'url': 'https://api.github.com/repos/zwqjsj0404/BigData',
#    'forks_url': 'https://api.github.com/repos/zwqjsj0404/BigData/forks',
#    'keys_url': 'https://api.github.com/repos/zwqjsj0404/BigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/zwqjsj0404/BigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/zwqjsj0404/BigData/teams',
#    'hooks_url': 'https://api.github.com/repos/zwqjsj0404/BigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/zwqjsj0404/BigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/zwqjsj0404/BigData/events',
#    'assignees_url': 'https://api.github.com/repos/zwqjsj0404/BigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/zwqjsj0404/BigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/zwqjsj0404/BigData/tags',
#    'blobs_url': 'https://api.github.com/repos/zwqjsj0404/BigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/zwqjsj0404/BigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/zwqjsj0404/BigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/zwqjsj0404/BigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/zwqjsj0404/BigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/zwqjsj0404/BigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/zwqjsj0404/BigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/zwqjsj0404/BigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/zwqjsj0404/BigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/zwqjsj0404/BigData/subscription',
#    'commits_url': 'https://api.github.com/repos/zwqjsj0404/BigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/zwqjsj0404/BigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/zwqjsj0404/BigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/zwqjsj0404/BigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/zwqjsj0404/BigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/zwqjsj0404/BigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/zwqjsj0404/BigData/merges',
#    'archive_url': 'https://api.github.com/repos/zwqjsj0404/BigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/zwqjsj0404/BigData/downloads',
#    'issues_url': 'https://api.github.com/repos/zwqjsj0404/BigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/zwqjsj0404/BigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/zwqjsj0404/BigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/zwqjsj0404/BigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/zwqjsj0404/BigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/zwqjsj0404/BigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/zwqjsj0404/BigData/deployments',
#    'created_at': '2013-03-10T06:09:43Z',
#    'updated_at': '2023-09-20T09:58:14Z',
#    'pushed_at': '2013-03-10T04:11:29Z',
#    'git_url': 'git://github.com/zwqjsj0404/BigData.git',
#    'ssh_url': 'git@github.com:zwqjsj0404/BigData.git',
#    'clone_url': 'https://github.com/zwqjsj0404/BigData.git',
#    'svn_url': 'https://github.com/zwqjsj0404/BigData',
#    'homepage': None,
#    'size': 93153,
#    'stargazers_count': 29,
#    'watchers_count': 29,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 65,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 65,
#    'open_issues': 0,
#    'watchers': 29,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 21500692,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTUwMDY5Mg==',
#    'name': 'awesome-bigdata',
#    'full_name': 'newTendermint/awesome-bigdata',
#    'private': False,
#    'owner': {'login': 'newTendermint',
#     'id': 1712926,
#     'node_id': 'MDQ6VXNlcjE3MTI5MjY=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/1712926?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/newTendermint',
#     'html_url': 'https://github.com/newTendermint',
#     'followers_url': 'https://api.github.com/users/newTendermint/followers',
#     'following_url': 'https://api.github.com/users/newTendermint/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/newTendermint/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/newTendermint/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/newTendermint/subscriptions',
#     'organizations_url': 'https://api.github.com/users/newTendermint/orgs',
#     'repos_url': 'https://api.github.com/users/newTendermint/repos',
#     'events_url': 'https://api.github.com/users/newTendermint/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/newTendermint/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/newTendermint/awesome-bigdata',
#    'description': 'A curated list of awesome big data frameworks, ressources and other awesomeness.',
#    'fork': False,
#    'url': 'https://api.github.com/repos/newTendermint/awesome-bigdata',
#    'forks_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/forks',
#    'keys_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/teams',
#    'hooks_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/hooks',
#    'issue_events_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/events',
#    'assignees_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/tags',
#    'blobs_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/languages',
#    'stargazers_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/stargazers',
#    'contributors_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/contributors',
#    'subscribers_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/subscribers',
#    'subscription_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/subscription',
#    'commits_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/newTendermint/awesome-bigdata/issues/comments{/number}',
# ...
#     'url': 'https://api.github.com/users/sotowang',
#     'html_url': 'https://github.com/sotowang',
#     'followers_url': 'https://api.github.com/users/sotowang/followers',
#     'following_url': 'https://api.github.com/users/sotowang/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sotowang/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sotowang/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sotowang/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sotowang/orgs',
#     'repos_url': 'https://api.github.com/users/sotowang/repos',
#     'events_url': 'https://api.github.com/users/sotowang/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sotowang/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/sotowang/bigdata',
#    'description': 'Java 大数据学习笔记',
#    'fork': False,
#    'url': 'https://api.github.com/repos/sotowang/bigdata',
#    'forks_url': 'https://api.github.com/repos/sotowang/bigdata/forks',
#    'keys_url': 'https://api.github.com/repos/sotowang/bigdata/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sotowang/bigdata/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sotowang/bigdata/teams',
#    'hooks_url': 'https://api.github.com/repos/sotowang/bigdata/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sotowang/bigdata/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sotowang/bigdata/events',
#    'assignees_url': 'https://api.github.com/repos/sotowang/bigdata/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sotowang/bigdata/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sotowang/bigdata/tags',
#    'blobs_url': 'https://api.github.com/repos/sotowang/bigdata/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sotowang/bigdata/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sotowang/bigdata/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sotowang/bigdata/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sotowang/bigdata/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sotowang/bigdata/languages',
#    'stargazers_url': 'https://api.github.com/repos/sotowang/bigdata/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sotowang/bigdata/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sotowang/bigdata/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sotowang/bigdata/subscription',
#    'commits_url': 'https://api.github.com/repos/sotowang/bigdata/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sotowang/bigdata/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sotowang/bigdata/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sotowang/bigdata/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sotowang/bigdata/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sotowang/bigdata/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sotowang/bigdata/merges',
#    'archive_url': 'https://api.github.com/repos/sotowang/bigdata/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sotowang/bigdata/downloads',
#    'issues_url': 'https://api.github.com/repos/sotowang/bigdata/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sotowang/bigdata/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sotowang/bigdata/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sotowang/bigdata/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sotowang/bigdata/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sotowang/bigdata/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sotowang/bigdata/deployments',
#    'created_at': '2019-01-17T09:28:09Z',
#    'updated_at': '2023-09-02T09:22:28Z',
#    'pushed_at': '2020-09-02T14:01:24Z',
#    'git_url': 'git://github.com/sotowang/bigdata.git',
#    'ssh_url': 'git@github.com:sotowang/bigdata.git',
#    'clone_url': 'https://github.com/sotowang/bigdata.git',
#    'svn_url': 'https://github.com/sotowang/bigdata',
#    'homepage': '',
#    'size': 12699,
#    'stargazers_count': 30,
#    'watchers_count': 30,
#    'language': None,
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 13,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 13,
#    'open_issues': 1,
#    'watchers': 30,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 178249274,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzgyNDkyNzQ=',
#    'name': 'bigdata',
#    'full_name': 'rolandmueller/bigdata',
#    'private': False,
#    'owner': {'login': 'rolandmueller',
#     'id': 459179,
#     'node_id': 'MDQ6VXNlcjQ1OTE3OQ==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/459179?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/rolandmueller',
#     'html_url': 'https://github.com/rolandmueller',
#     'followers_url': 'https://api.github.com/users/rolandmueller/followers',
#     'following_url': 'https://api.github.com/users/rolandmueller/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/rolandmueller/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/rolandmueller/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/rolandmueller/subscriptions',
#     'organizations_url': 'https://api.github.com/users/rolandmueller/orgs',
#     'repos_url': 'https://api.github.com/users/rolandmueller/repos',
#     'events_url': 'https://api.github.com/users/rolandmueller/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/rolandmueller/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/rolandmueller/bigdata',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/rolandmueller/bigdata',
#    'forks_url': 'https://api.github.com/repos/rolandmueller/bigdata/forks',
#    'keys_url': 'https://api.github.com/repos/rolandmueller/bigdata/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/rolandmueller/bigdata/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/rolandmueller/bigdata/teams',
#    'hooks_url': 'https://api.github.com/repos/rolandmueller/bigdata/hooks',
#    'issue_events_url': 'https://api.github.com/repos/rolandmueller/bigdata/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/rolandmueller/bigdata/events',
#    'assignees_url': 'https://api.github.com/repos/rolandmueller/bigdata/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/rolandmueller/bigdata/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/rolandmueller/bigdata/tags',
#    'blobs_url': 'https://api.github.com/repos/rolandmueller/bigdata/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/rolandmueller/bigdata/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/rolandmueller/bigdata/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/rolandmueller/bigdata/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/rolandmueller/bigdata/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/rolandmueller/bigdata/languages',
#    'stargazers_url': 'https://api.github.com/repos/rolandmueller/bigdata/stargazers',
#    'contributors_url': 'https://api.github.com/repos/rolandmueller/bigdata/contributors',
#    'subscribers_url': 'https://api.github.com/repos/rolandmueller/bigdata/subscribers',
#    'subscription_url': 'https://api.github.com/repos/rolandmueller/bigdata/subscription',
#    'commits_url': 'https://api.github.com/repos/rolandmueller/bigdata/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/rolandmueller/bigdata/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/rolandmueller/bigdata/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/rolandmueller/bigdata/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/rolandmueller/bigdata/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/rolandmueller/bigdata/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/rolandmueller/bigdata/merges',
#    'archive_url': 'https://api.github.com/repos/rolandmueller/bigdata/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/rolandmueller/bigdata/downloads',
#    'issues_url': 'https://api.github.com/repos/rolandmueller/bigdata/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/rolandmueller/bigdata/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/rolandmueller/bigdata/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/rolandmueller/bigdata/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/rolandmueller/bigdata/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/rolandmueller/bigdata/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/rolandmueller/bigdata/deployments',
#    'created_at': '2019-03-28T17:11:15Z',
#    'updated_at': '2023-04-14T07:54:25Z',
#    'pushed_at': '2023-07-10T11:17:04Z',
#    'git_url': 'git://github.com/rolandmueller/bigdata.git',
#    'ssh_url': 'git@github.com:rolandmueller/bigdata.git',
#    'clone_url': 'https://github.com/rolandmueller/bigdata.git',
#    'svn_url': 'https://github.com/rolandmueller/bigdata',
#    'homepage': None,
#    'size': 16554,
#    'stargazers_count': 1,
#    'watchers_count': 1,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 49,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 49,
#    'open_issues': 0,
#    'watchers': 1,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 11227323,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxMTIyNzMyMw==',
#    'name': 'bigData',
#    'full_name': 'alfredkam/bigData',
#    'private': False,
#    'owner': {'login': 'alfredkam',
#     'id': 1495567,
#     'node_id': 'MDQ6VXNlcjE0OTU1Njc=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/1495567?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/alfredkam',
#     'html_url': 'https://github.com/alfredkam',
#     'followers_url': 'https://api.github.com/users/alfredkam/followers',
#     'following_url': 'https://api.github.com/users/alfredkam/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/alfredkam/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/alfredkam/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/alfredkam/subscriptions',
#     'organizations_url': 'https://api.github.com/users/alfredkam/orgs',
#     'repos_url': 'https://api.github.com/users/alfredkam/repos',
#     'events_url': 'https://api.github.com/users/alfredkam/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/alfredkam/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/alfredkam/bigData',
#    'description': 'Essential Node Js Modules / Tools for data mining ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/alfredkam/bigData',
#    'forks_url': 'https://api.github.com/repos/alfredkam/bigData/forks',
#    'keys_url': 'https://api.github.com/repos/alfredkam/bigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/alfredkam/bigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/alfredkam/bigData/teams',
#    'hooks_url': 'https://api.github.com/repos/alfredkam/bigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/alfredkam/bigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/alfredkam/bigData/events',
#    'assignees_url': 'https://api.github.com/repos/alfredkam/bigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/alfredkam/bigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/alfredkam/bigData/tags',
#    'blobs_url': 'https://api.github.com/repos/alfredkam/bigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/alfredkam/bigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/alfredkam/bigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/alfredkam/bigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/alfredkam/bigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/alfredkam/bigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/alfredkam/bigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/alfredkam/bigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/alfredkam/bigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/alfredkam/bigData/subscription',
#    'commits_url': 'https://api.github.com/repos/alfredkam/bigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/alfredkam/bigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/alfredkam/bigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/alfredkam/bigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/alfredkam/bigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/alfredkam/bigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/alfredkam/bigData/merges',
#    'archive_url': 'https://api.github.com/repos/alfredkam/bigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/alfredkam/bigData/downloads',
#    'issues_url': 'https://api.github.com/repos/alfredkam/bigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/alfredkam/bigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/alfredkam/bigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/alfredkam/bigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/alfredkam/bigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/alfredkam/bigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/alfredkam/bigData/deployments',
#    'created_at': '2013-07-07T02:21:21Z',
#    'updated_at': '2022-09-29T21:03:04Z',
#    'pushed_at': '2016-07-04T21:47:33Z',
#    'git_url': 'git://github.com/alfredkam/bigData.git',
#    'ssh_url': 'git@github.com:alfredkam/bigData.git',
#    'clone_url': 'https://github.com/alfredkam/bigData.git',
#    'svn_url': 'https://github.com/alfredkam/bigData',
#    'homepage': '',
#    'size': 20,
#    'stargazers_count': 17,
#    'watchers_count': 17,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 14,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 14,
#    'open_issues': 1,
#    'watchers': 17,
#    'default_branch': 'master',
#    'score': 1.0}]}

# %%
# Check how many elements I get as answers
response.json()['total_count']
# Out:
# 39955

# %%
# limit or number of results displayed
response.json()
response = requests.get(url,
                       params={'q': 'bigdata in:name','per_page':5})
response.json()
# Out:
# {'total_count': 42678,
#  'incomplete_results': False,
#  'items': [{'id': 215028549,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyMTUwMjg1NDk=',
#    'name': 'bigData',
#    'full_name': 'hyh1750522171/bigData',
#    'private': False,
#    'owner': {'login': 'hyh1750522171',
#     'id': 35066516,
#     'node_id': 'MDQ6VXNlcjM1MDY2NTE2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/35066516?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/hyh1750522171',
#     'html_url': 'https://github.com/hyh1750522171',
#     'followers_url': 'https://api.github.com/users/hyh1750522171/followers',
#     'following_url': 'https://api.github.com/users/hyh1750522171/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/hyh1750522171/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/hyh1750522171/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/hyh1750522171/subscriptions',
#     'organizations_url': 'https://api.github.com/users/hyh1750522171/orgs',
#     'repos_url': 'https://api.github.com/users/hyh1750522171/repos',
#     'events_url': 'https://api.github.com/users/hyh1750522171/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/hyh1750522171/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/hyh1750522171/bigData',
#    'description': '大数据比赛项目库',
#    'fork': False,
#    'url': 'https://api.github.com/repos/hyh1750522171/bigData',
#    'forks_url': 'https://api.github.com/repos/hyh1750522171/bigData/forks',
#    'keys_url': 'https://api.github.com/repos/hyh1750522171/bigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/hyh1750522171/bigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/hyh1750522171/bigData/teams',
#    'hooks_url': 'https://api.github.com/repos/hyh1750522171/bigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/hyh1750522171/bigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/hyh1750522171/bigData/events',
#    'assignees_url': 'https://api.github.com/repos/hyh1750522171/bigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/hyh1750522171/bigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/hyh1750522171/bigData/tags',
#    'blobs_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/hyh1750522171/bigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/hyh1750522171/bigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/hyh1750522171/bigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/hyh1750522171/bigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/hyh1750522171/bigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/hyh1750522171/bigData/subscription',
#    'commits_url': 'https://api.github.com/repos/hyh1750522171/bigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/hyh1750522171/bigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/hyh1750522171/bigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/hyh1750522171/bigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/hyh1750522171/bigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/hyh1750522171/bigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/hyh1750522171/bigData/merges',
#    'archive_url': 'https://api.github.com/repos/hyh1750522171/bigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/hyh1750522171/bigData/downloads',
#    'issues_url': 'https://api.github.com/repos/hyh1750522171/bigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/hyh1750522171/bigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/hyh1750522171/bigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/hyh1750522171/bigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/hyh1750522171/bigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/hyh1750522171/bigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/hyh1750522171/bigData/deployments',
#    'created_at': '2019-10-14T11:41:48Z',
#    'updated_at': '2024-01-05T09:42:22Z',
#    'pushed_at': '2023-02-17T02:29:42Z',
#    'git_url': 'git://github.com/hyh1750522171/bigData.git',
#    'ssh_url': 'git@github.com:hyh1750522171/bigData.git',
#    'clone_url': 'https://github.com/hyh1750522171/bigData.git',
#    'svn_url': 'https://github.com/hyh1750522171/bigData',
#    'homepage': None,
#    'size': 28619,
#    'stargazers_count': 663,
#    'watchers_count': 663,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 545,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': None,
#    'allow_forking': True,
#    'is_template': True,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 545,
#    'open_issues': 2,
#    'watchers': 663,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 74181851,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk3NDE4MTg1MQ==',
#    'name': 'BigData',
#    'full_name': 'monsonlee/BigData',
#    'private': False,
#    'owner': {'login': 'monsonlee',
#     'id': 17783047,
#     'node_id': 'MDQ6VXNlcjE3NzgzMDQ3',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/17783047?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/monsonlee',
#     'html_url': 'https://github.com/monsonlee',
#     'followers_url': 'https://api.github.com/users/monsonlee/followers',
#     'following_url': 'https://api.github.com/users/monsonlee/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/monsonlee/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/monsonlee/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/monsonlee/subscriptions',
#     'organizations_url': 'https://api.github.com/users/monsonlee/orgs',
#     'repos_url': 'https://api.github.com/users/monsonlee/repos',
#     'events_url': 'https://api.github.com/users/monsonlee/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/monsonlee/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/monsonlee/BigData',
#    'description': 'BigData Project 大数据项目由浅入深',
#    'fork': False,
#    'url': 'https://api.github.com/repos/monsonlee/BigData',
#    'forks_url': 'https://api.github.com/repos/monsonlee/BigData/forks',
#    'keys_url': 'https://api.github.com/repos/monsonlee/BigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/monsonlee/BigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/monsonlee/BigData/teams',
#    'hooks_url': 'https://api.github.com/repos/monsonlee/BigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/monsonlee/BigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/monsonlee/BigData/events',
#    'assignees_url': 'https://api.github.com/repos/monsonlee/BigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/monsonlee/BigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/monsonlee/BigData/tags',
#    'blobs_url': 'https://api.github.com/repos/monsonlee/BigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/monsonlee/BigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/monsonlee/BigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/monsonlee/BigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/monsonlee/BigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/monsonlee/BigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/monsonlee/BigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/monsonlee/BigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/monsonlee/BigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/monsonlee/BigData/subscription',
#    'commits_url': 'https://api.github.com/repos/monsonlee/BigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/monsonlee/BigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/monsonlee/BigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/monsonlee/BigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/monsonlee/BigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/monsonlee/BigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/monsonlee/BigData/merges',
#    'archive_url': 'https://api.github.com/repos/monsonlee/BigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/monsonlee/BigData/downloads',
#    'issues_url': 'https://api.github.com/repos/monsonlee/BigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/monsonlee/BigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/monsonlee/BigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/monsonlee/BigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/monsonlee/BigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/monsonlee/BigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/monsonlee/BigData/deployments',
#    'created_at': '2016-11-19T02:25:14Z',
#    'updated_at': '2024-01-09T23:31:58Z',
#    'pushed_at': '2017-11-30T08:33:11Z',
#    'git_url': 'git://github.com/monsonlee/BigData.git',
#    'ssh_url': 'git@github.com:monsonlee/BigData.git',
#    'clone_url': 'https://github.com/monsonlee/BigData.git',
#    'svn_url': 'https://github.com/monsonlee/BigData',
#    'homepage': '',
#    'size': 1494,
#    'stargazers_count': 619,
#    'watchers_count': 619,
#    'language': 'Java',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 292,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': {'key': 'gpl-3.0',
#     'name': 'GNU General Public License v3.0',
#     'spdx_id': 'GPL-3.0',
#     'url': 'https://api.github.com/licenses/gpl-3.0',
#     'node_id': 'MDc6TGljZW5zZTk='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 292,
#    'open_issues': 2,
#    'watchers': 619,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 140367143,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNDAzNjcxNDM=',
#    'name': 'BigData',
#    'full_name': 'sunnyandgood/BigData',
#    'private': False,
#    'owner': {'login': 'sunnyandgood',
#     'id': 33865475,
#     'node_id': 'MDQ6VXNlcjMzODY1NDc1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/33865475?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/sunnyandgood',
#     'html_url': 'https://github.com/sunnyandgood',
#     'followers_url': 'https://api.github.com/users/sunnyandgood/followers',
#     'following_url': 'https://api.github.com/users/sunnyandgood/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/sunnyandgood/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/sunnyandgood/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/sunnyandgood/subscriptions',
#     'organizations_url': 'https://api.github.com/users/sunnyandgood/orgs',
#     'repos_url': 'https://api.github.com/users/sunnyandgood/repos',
#     'events_url': 'https://api.github.com/users/sunnyandgood/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/sunnyandgood/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/sunnyandgood/BigData',
#    'description': '💎🔥大数据学习笔记',
#    'fork': False,
#    'url': 'https://api.github.com/repos/sunnyandgood/BigData',
#    'forks_url': 'https://api.github.com/repos/sunnyandgood/BigData/forks',
#    'keys_url': 'https://api.github.com/repos/sunnyandgood/BigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/sunnyandgood/BigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/sunnyandgood/BigData/teams',
#    'hooks_url': 'https://api.github.com/repos/sunnyandgood/BigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/sunnyandgood/BigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/sunnyandgood/BigData/events',
#    'assignees_url': 'https://api.github.com/repos/sunnyandgood/BigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/sunnyandgood/BigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/sunnyandgood/BigData/tags',
#    'blobs_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/sunnyandgood/BigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/sunnyandgood/BigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/sunnyandgood/BigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/sunnyandgood/BigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/sunnyandgood/BigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/sunnyandgood/BigData/subscription',
#    'commits_url': 'https://api.github.com/repos/sunnyandgood/BigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/sunnyandgood/BigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/sunnyandgood/BigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/sunnyandgood/BigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/sunnyandgood/BigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/sunnyandgood/BigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/sunnyandgood/BigData/merges',
#    'archive_url': 'https://api.github.com/repos/sunnyandgood/BigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/sunnyandgood/BigData/downloads',
#    'issues_url': 'https://api.github.com/repos/sunnyandgood/BigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/sunnyandgood/BigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/sunnyandgood/BigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/sunnyandgood/BigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/sunnyandgood/BigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/sunnyandgood/BigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/sunnyandgood/BigData/deployments',
#    'created_at': '2018-07-10T02:37:47Z',
#    'updated_at': '2024-01-08T01:33:51Z',
#    'pushed_at': '2019-05-13T12:04:24Z',
#    'git_url': 'git://github.com/sunnyandgood/BigData.git',
#    'ssh_url': 'git@github.com:sunnyandgood/BigData.git',
#    'clone_url': 'https://github.com/sunnyandgood/BigData.git',
#    'svn_url': 'https://github.com/sunnyandgood/BigData',
#    'homepage': '',
#    'size': 331418,
#    'stargazers_count': 658,
#    'watchers_count': 658,
#    'language': 'Java',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 224,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 2,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['flume',
#     'hadoop',
#     'hbase',
#     'hdfs',
#     'hive',
#     'linux',
#     'mapreduce',
#     'mysql',
#     'shell',
#     'sqoop',
#     'zookeeper'],
#    'visibility': 'public',
#    'forks': 224,
#    'open_issues': 2,
#    'watchers': 658,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 57103571,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk1NzEwMzU3MQ==',
#    'name': 'BigData',
#    'full_name': 'minsuk-heo/BigData',
#    'private': False,
#    'owner': {'login': 'minsuk-heo',
#     'id': 14434896,
#     'node_id': 'MDQ6VXNlcjE0NDM0ODk2',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/14434896?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/minsuk-heo',
#     'html_url': 'https://github.com/minsuk-heo',
#     'followers_url': 'https://api.github.com/users/minsuk-heo/followers',
#     'following_url': 'https://api.github.com/users/minsuk-heo/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/minsuk-heo/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/minsuk-heo/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/minsuk-heo/subscriptions',
#     'organizations_url': 'https://api.github.com/users/minsuk-heo/orgs',
#     'repos_url': 'https://api.github.com/users/minsuk-heo/repos',
#     'events_url': 'https://api.github.com/users/minsuk-heo/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/minsuk-heo/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/minsuk-heo/BigData',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/minsuk-heo/BigData',
#    'forks_url': 'https://api.github.com/repos/minsuk-heo/BigData/forks',
#    'keys_url': 'https://api.github.com/repos/minsuk-heo/BigData/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/minsuk-heo/BigData/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/minsuk-heo/BigData/teams',
#    'hooks_url': 'https://api.github.com/repos/minsuk-heo/BigData/hooks',
#    'issue_events_url': 'https://api.github.com/repos/minsuk-heo/BigData/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/minsuk-heo/BigData/events',
#    'assignees_url': 'https://api.github.com/repos/minsuk-heo/BigData/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/minsuk-heo/BigData/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/minsuk-heo/BigData/tags',
#    'blobs_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/minsuk-heo/BigData/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/minsuk-heo/BigData/languages',
#    'stargazers_url': 'https://api.github.com/repos/minsuk-heo/BigData/stargazers',
#    'contributors_url': 'https://api.github.com/repos/minsuk-heo/BigData/contributors',
#    'subscribers_url': 'https://api.github.com/repos/minsuk-heo/BigData/subscribers',
#    'subscription_url': 'https://api.github.com/repos/minsuk-heo/BigData/subscription',
#    'commits_url': 'https://api.github.com/repos/minsuk-heo/BigData/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/minsuk-heo/BigData/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/minsuk-heo/BigData/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/minsuk-heo/BigData/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/minsuk-heo/BigData/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/minsuk-heo/BigData/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/minsuk-heo/BigData/merges',
#    'archive_url': 'https://api.github.com/repos/minsuk-heo/BigData/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/minsuk-heo/BigData/downloads',
#    'issues_url': 'https://api.github.com/repos/minsuk-heo/BigData/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/minsuk-heo/BigData/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/minsuk-heo/BigData/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/minsuk-heo/BigData/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/minsuk-heo/BigData/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/minsuk-heo/BigData/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/minsuk-heo/BigData/deployments',
#    'created_at': '2016-04-26T06:27:16Z',
#    'updated_at': '2024-01-10T16:13:31Z',
#    'pushed_at': '2021-01-03T06:55:58Z',
#    'git_url': 'git://github.com/minsuk-heo/BigData.git',
#    'ssh_url': 'git@github.com:minsuk-heo/BigData.git',
#    'clone_url': 'https://github.com/minsuk-heo/BigData.git',
#    'svn_url': 'https://github.com/minsuk-heo/BigData',
#    'homepage': None,
#    'size': 63,
#    'stargazers_count': 164,
#    'watchers_count': 164,
#    'language': 'Shell',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 243,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 243,
#    'open_issues': 1,
#    'watchers': 164,
#    'default_branch': 'master',
#    'score': 1.0},
#   {'id': 43791031,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0Mzc5MTAzMQ==',
#    'name': 'bigdata',
#    'full_name': 'haifengl/bigdata',
#    'private': False,
#    'owner': {'login': 'haifengl',
#     'id': 5502052,
#     'node_id': 'MDQ6VXNlcjU1MDIwNTI=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/5502052?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/haifengl',
#     'html_url': 'https://github.com/haifengl',
#     'followers_url': 'https://api.github.com/users/haifengl/followers',
#     'following_url': 'https://api.github.com/users/haifengl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/haifengl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/haifengl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/haifengl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/haifengl/orgs',
#     'repos_url': 'https://api.github.com/users/haifengl/repos',
#     'events_url': 'https://api.github.com/users/haifengl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/haifengl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'html_url': 'https://github.com/haifengl/bigdata',
#    'description': 'Introduction to Big Data',
#    'fork': False,
#    'url': 'https://api.github.com/repos/haifengl/bigdata',
#    'forks_url': 'https://api.github.com/repos/haifengl/bigdata/forks',
#    'keys_url': 'https://api.github.com/repos/haifengl/bigdata/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/haifengl/bigdata/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/haifengl/bigdata/teams',
#    'hooks_url': 'https://api.github.com/repos/haifengl/bigdata/hooks',
#    'issue_events_url': 'https://api.github.com/repos/haifengl/bigdata/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/haifengl/bigdata/events',
#    'assignees_url': 'https://api.github.com/repos/haifengl/bigdata/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/haifengl/bigdata/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/haifengl/bigdata/tags',
#    'blobs_url': 'https://api.github.com/repos/haifengl/bigdata/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/haifengl/bigdata/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/haifengl/bigdata/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/haifengl/bigdata/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/haifengl/bigdata/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/haifengl/bigdata/languages',
#    'stargazers_url': 'https://api.github.com/repos/haifengl/bigdata/stargazers',
#    'contributors_url': 'https://api.github.com/repos/haifengl/bigdata/contributors',
#    'subscribers_url': 'https://api.github.com/repos/haifengl/bigdata/subscribers',
#    'subscription_url': 'https://api.github.com/repos/haifengl/bigdata/subscription',
#    'commits_url': 'https://api.github.com/repos/haifengl/bigdata/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/haifengl/bigdata/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/haifengl/bigdata/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/haifengl/bigdata/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/haifengl/bigdata/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/haifengl/bigdata/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/haifengl/bigdata/merges',
#    'archive_url': 'https://api.github.com/repos/haifengl/bigdata/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/haifengl/bigdata/downloads',
#    'issues_url': 'https://api.github.com/repos/haifengl/bigdata/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/haifengl/bigdata/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/haifengl/bigdata/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/haifengl/bigdata/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/haifengl/bigdata/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/haifengl/bigdata/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/haifengl/bigdata/deployments',
#    'created_at': '2015-10-07T02:34:22Z',
#    'updated_at': '2024-01-01T16:50:10Z',
#    'pushed_at': '2019-11-20T15:01:02Z',
#    'git_url': 'git://github.com/haifengl/bigdata.git',
#    'ssh_url': 'git@github.com:haifengl/bigdata.git',
#    'clone_url': 'https://github.com/haifengl/bigdata.git',
#    'svn_url': 'https://github.com/haifengl/bigdata',
#    'homepage': None,
#    'size': 3384,
#    'stargazers_count': 389,
#    'watchers_count': 389,
#    'language': 'TeX',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': True,
#    'has_discussions': False,
#    'forks_count': 150,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'gpl-2.0',
#     'name': 'GNU General Public License v2.0',
#     'spdx_id': 'GPL-2.0',
#     'url': 'https://api.github.com/licenses/gpl-2.0',
#     'node_id': 'MDc6TGljZW5zZTg='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 150,
#    'open_issues': 0,
#    'watchers': 389,
#    'default_branch': 'master',
#    'score': 1.0}]}

# %%
# In the response there are several fields, including a list of items.
# Access to the url of the first two repos
repo1 = response.json()['items'][0]['html_url']
repo1
# Out:
# 'https://github.com/hyh1750522171/bigData'

# %%
# To access the address of the second of the repos
repo2 = response.json()['items'][1]['html_url']
repo2
# Out:
# 'https://github.com/monsonlee/BigData'

# %%
# Example with HTTPBin (in local - docker)
# We do not pass any "argument = args".
url = 'http://localhost/get'
response = requests.get(url)
response.json()
# Out:
# {'args': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'keep-alive',
#   'Host': 'localhost',
#   'User-Agent': 'python-requests/2.31.0'},
#  'origin': '172.17.0.1',
#  'url': 'http://localhost/get'}

# %%
# We pass a key argument: value
# Check how the URL is constructed (try to open it with the browser)
url = 'http://localhost/get'
response = requests.get(url,
                       params = {'key':'value'})
response.json()
# Out:
# {'args': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'keep-alive',
#   'Host': 'localhost',
#   'User-Agent': 'python-requests/2.31.0'},
#  'origin': '172.17.0.1',
#  'url': 'http://localhost/get?key=value'}

# %%
# We pass two pairs of arguments
# Check how the URL is constructed (try to open it with the browser)
url = 'http://localhost/get'
response = requests.get(url,
                       params = {'nome':'fulanito','apelido':'menganez'})
response.json()
# Out:
# {'args': {'apelido': 'menganez', 'nome': 'fulanito'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'keep-alive',
#   'Host': 'localhost',
#   'User-Agent': 'python-requests/2.31.0'},
#  'origin': '172.17.0.1',
#  'url': 'http://localhost/get?nome=fulanito&apelido=menganez'}

# %% [markdown]
# **PAYLOAD**
#
# In computing and telecommunications the payload is the set of transmitted data which is actually the message sent. The payload excludes the headers or metadata, which are sent simply to facilitate the delivery of the message. The term is borrowed from freight transport, where payload refers to that part of the cargo which is used to pay for the transport.

# %%
## PAYLOAD
# En informática y telecomunicaciones la carga útil1(payload en inglés) es el conjunto de datos
# transmitidos que es en realidad el mensaje enviado. La carga útil excluye las cabeceras o metadatos,
# que son enviados simplemente para facilitar la entrega del mensaje. El término está tomado prestado
# del transporte de mercancías, donde carga útil se refiere a la parte de la carga que se utiliza 
# para costear el transporte. 

url = 'http://localhost/get'
payload = {'nome':'fulanito','apelido':'menganez'}
response = requests.get(url,
                       params = payload)
response.json()
# Out:
# {'args': {'apelido': 'menganez', 'nome': 'fulanito'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'keep-alive',
#   'Host': 'localhost',
#   'User-Agent': 'python-requests/2.31.0'},
#  'origin': '172.17.0.1',
#  'url': 'http://localhost/get?nome=fulanito&apelido=menganez'}

# %%
# In summary, some endpoints support or require the sending of parameters to provide a response.

# %%
### REQUEST HEADERS
# In addition to modifying the requests by adding parameters you can also parameterise the requests 
# through the headers or REQUEST HEADERS

# %%
# Example with HTTPBin (local - docker)
# Look at our "default" HEADERS
url = 'http://localhost/get'
response = requests.get(url)
response.json()
# Out:
# {'args': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'keep-alive',
#   'Host': 'localhost',
#   'User-Agent': 'python-requests/2.31.0'},
#  'origin': '172.17.0.1',
#  'url': 'http://localhost/get'}

# %%
# We can falsify the "user-agent", i.e., who is making the requests.
response = requests.get(url,
                     headers={'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0;Win64;x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'})
response.json()
# Out:
# {'args': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'keep-alive',
#   'Host': 'localhost',
#   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0;Win64;x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'},
#  'origin': '172.17.0.1',
#  'url': 'http://localhost/get'}

# %%
response = requests.get(url,
                     headers={'usuario' : 'dani', 'pass' : 'changeme'},params={'ciudad' : 'lugo'})
response.json()
# Out:
# {'args': {'ciudad': 'lugo'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'keep-alive',
#   'Host': 'localhost',
#   'Pass': 'changeme',
#   'User-Agent': 'python-requests/2.31.0',
#   'Usuario': 'dani'},
#  'origin': '172.17.0.1',
#  'url': 'http://localhost/get?ciudad=lugo'}

# %%
# We can falsify the "user-agent", i.e. who is making the requests (we can actually add anything).
response = requests.get(url,
                     headers={'User-Agent' : 'Macanudo Browser 5.1'})
response.json()
# Out:
# {'args': {},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'keep-alive',
#   'Host': 'localhost',
#   'User-Agent': 'Macanudo Browser 5.1'},
#  'origin': '172.17.0.1',
#  'url': 'http://localhost/get'}

# %%
# Some applications require us to indicate which formats we accept in our responses.
# It is common to indicate: application/json
response = requests.get(url,
                     headers={'User-Agent' : 'Macanudo Browser 5.1','Accept':'application/json'})
response.json()
# Out:
# {'args': {},
#  'headers': {'Accept': 'application/json',
#   'Accept-Encoding': 'gzip, deflate',
#   'Connection': 'keep-alive',
#   'Host': 'localhost',
#   'User-Agent': 'Macanudo Browser 5.1'},
#  'origin': '172.17.0.1',
#  'url': 'http://localhost/get'}

# %%
# Show the same request through the browser by navigating to api
# http://localhost/get <- different user-agent

# %%
# Show the same request through CURL
# curl -X GET "http://localhost/get" -H "accept: application/json"
# On Windows, download CURL
# https://curl.se/windows/

# curl -X == --request <command> -> curl -X GET (for example) or curl -X PUT
# -H "accept: application/json" <- pass in headers do request
# Indicates the type of response we will accept
